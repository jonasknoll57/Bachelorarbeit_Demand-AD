# %% [markdown]
# <a href="https://colab.research.google.com/github/jonasknoll57/Bachelorarbeit_Demand-AD/blob/main/V3_Exp03_More_Pairs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exp3 — Single-Source Pre-Train + Fine-Tune (mit Transfer-Strategien)
#
# **Zweck:** Untersuchen, ob und wie ein Source-Modell mit Target-Daten adaptiert werden kann.
#
# **Drei Transfer-Strategien** (inspiriert von TensorFlow Transfer Learning Guide):
#
# | Strategie | Beschreibung | Trainierbare Layer |
# |-----------|-------------|-------------------|
# | **A) Feature Extraction** | LSTM-Backbone eingefroren, nur neuer Output-Head | `forecast_output` (Dense) |
# | **B) Partial Fine-Tune** | Phase 1: Frozen Backbone. Phase 2: Oberes LSTM + Head mit niedriger LR | `forecast_lstm_2` + `forecast_output` |
# | **C) Full Fine-Tune** | Alle Layer trainierbar mit niedriger LR | Alle |
#
# **Analogie zum TF-Guide:** Feature Extraction = `base_model.trainable = False` + neuer Head.
# Partial Fine-Tune = erst frozen trainieren, dann top layers unfreezen. Full Fine-Tune = alles offen.
#
# **Evaluation:** Strict (Source-Threshold) + Fair (Target-Val Z-Norm) + Raw PR-AUC

# %%
# ══════════════════════════════════════════════════════════════
# 0a — Colab Setup
# ══════════════════════════════════════════════════════════════
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ══════════════════════════════════════════════════════════════
# 0b — Imports
# ══════════════════════════════════════════════════════════════
import os, math, json, random, warnings, time, re, glob, copy, pickle
from dataclasses import dataclass, field, asdict
from typing import List, Dict, Optional, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import poisson
from scipy.spatial.distance import cdist
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import (
    roc_auc_score, average_precision_score, f1_score,
    precision_score, recall_score, precision_recall_curve,
    classification_report
)
from numpy.lib.stride_tricks import sliding_window_view

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

warnings.filterwarnings("ignore")
print(f"TF {tf.__version__}, GPU: {tf.config.list_physical_devices('GPU')}")
# Out:
# TF 2.19.0, GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ══════════════════════════════════════════════════════════════
# 0c — Config (Exp2: Strict Zero-Shot, Multiple Source→Target Pairs)
# ══════════════════════════════════════════════════════════════
DATA_BASE    = '/content/drive/MyDrive/BA_Colab/data'
CLEANED_BASE = '/content/drive/MyDrive/BA_Colab/cleaned'

RUN_NAME    = 'exp02_zero_shot_strict_pairs'
RESULTS_DIR = f'{DATA_BASE}/{RUN_NAME}'
MODELS_DIR  = f'{RESULTS_DIR}/models'

# Quelle der bereits trainierten Exp01-Oracle-Modelle
SOURCE_RUN_NAME   = 'exp01_oracle_scarcity'
SOURCE_MODELS_DIR = f'{DATA_BASE}/{SOURCE_RUN_NAME}/models'

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)

# Paths
geo_path           = f'{CLEANED_BASE}/geo_information/geo_information.parquet'
station_names_path = f'{DATA_BASE}/station_names/station_names.parquet'

CITY_DEMAND = {
    "bochum":        f"{CLEANED_BASE}/demand/Bochum/demand_cleaned.parquet",
    "braunschweig":  f"{CLEANED_BASE}/demand/Braunschweig/demand_cleaned.parquet",
    "dortmund":      f"{CLEANED_BASE}/demand/Dortmund/demand_cleaned.parquet",
    "duisburg":      f"{CLEANED_BASE}/demand/Duisburg/demand_cleaned.parquet",
    "essen":         f"{CLEANED_BASE}/demand/Essen/demand_cleaned.parquet",
    "freiburg":      f"{CLEANED_BASE}/demand/Freiburg/demand_cleaned.parquet",
    "gießen":        f"{CLEANED_BASE}/demand/Gießen/demand_cleaned.parquet",
    "heidelberg":    f"{CLEANED_BASE}/demand/Heidelberg/demand_cleaned.parquet",
    "kaiserslautern":f"{CLEANED_BASE}/demand/Kaiserslautern/demand_cleaned.parquet",
    "kassel":        f"{CLEANED_BASE}/demand/Kassel/demand_cleaned.parquet",
    "leverkusen":    f"{CLEANED_BASE}/demand/Leverkusen/demand_cleaned.parquet",
    "ludwigshafen":  f"{CLEANED_BASE}/demand/Ludwigshafen/demand_cleaned.parquet",
    "mannheim":      f"{CLEANED_BASE}/demand/Mannheim/demand_cleaned.parquet",
    "marburg":       f"{CLEANED_BASE}/demand/Marburg/demand_cleaned.parquet",
    "offenburg":     f"{CLEANED_BASE}/demand/Offenburg/demand_cleaned.parquet",
    "wiesbaden":     f"{CLEANED_BASE}/demand/Wiesbaden/demand_cleaned.parquet",
    "winsen (Luhe)": f"{CLEANED_BASE}/demand/Winsen (Luhe)/demand_cleaned.parquet",
}

# Vorgegebene Exp2-Paare
TRANSFER_PAIRS = {
    "gießen": ["offenburg", "leverkusen", "marburg"],
    "dortmund": ["braunschweig", "marburg", "heidelberg"],
    "wiesbaden": ["ludwigshafen", "kaiserslautern", "heidelberg"],
}

PAIR_ROWS = [
    {"target_city": target_city, "source_city": source_city}
    for target_city, source_list in TRANSFER_PAIRS.items()
    for source_city in source_list
]

print("Geplante Zero-Shot-Paare:")
for target_city, source_list in TRANSFER_PAIRS.items():
    print(f"  Target {target_city}: {', '.join(source_list)}")

@dataclass
class V17bConfig:
    aggregation_minutes: int = 60
    train_ratio: float = 0.67
    val_ratio: float = 0.82
    min_events_per_day: float = 3.0
    rolling_days: int = 56
    min_context_obs: int = 20

    ae_window_size: int = 24
    ae_latent_dim: int = 32
    ae_layers: int = 2
    ae_dropout: float = 0.10
    ae_epochs: int = 50
    ae_batch_size: int = 2048
    ae_lr: float = 1e-3
    ae_early_stop: int = 8
    eval_batch_size: int = 2048

    low_demand_q: float = 0.33
    high_demand_q: float = 0.67

    require_contiguous: bool = True
    use_bidirectional: bool = False

    ae_features: List[str] = field(default_factory=lambda: [
        "n_lends", "n_returns",
        "hour_sin", "hour_cos", "dow_sin", "dow_cos",
        "month_sin", "month_cos", "is_weekend"
    ])
    ae_score_features: List[str] = field(default_factory=lambda: ["n_lends", "n_returns"])

    injection_rate: float = 0.015
    injection_seed: int = 42

cfg = V17bConfig()

ae_features    = list(cfg.ae_features)
score_features = list(cfg.ae_score_features)
context_steps  = cfg.ae_window_size - 1

print(f"Feature-Set: {len(ae_features)} Features → {ae_features}")
print(f"Score-Features: {score_features}")
print(f"Context Steps: {context_steps}")
print(f"Results: {RESULTS_DIR}")
print(f"Source models: {SOURCE_MODELS_DIR}")
# Out:
# Geplante Zero-Shot-Paare:
#   Target gießen: offenburg, leverkusen, marburg
#   Target dortmund: braunschweig, marburg, heidelberg
#   Target wiesbaden: ludwigshafen, kaiserslautern, heidelberg
# Feature-Set: 9 Features → ['n_lends', 'n_returns', 'hour_sin', 'hour_cos', 'dow_sin', 'dow_cos', 'month_sin', 'month_cos', 'is_weekend']
# Score-Features: ['n_lends', 'n_returns']
# Context Steps: 23
# Results: /content/drive/MyDrive/BA_Colab/data/exp02_zero_shot_strict_pairs
# Source models: /content/drive/MyDrive/BA_Colab/data/exp01_oracle_scarcity/models

# %% [markdown]
# ---
# ## Shared Functions (aus V22b/V17b 1:1 übernommen)

# %%
# ══════════════════════════════════════════════════════════════
# 1 — Aggregation
# ══════════════════════════════════════════════════════════════
def aggregate_station_level(df: pd.DataFrame, minutes: int = 60,
                            add_relative: bool = False) -> pd.DataFrame:
    out = df.copy()
    freq = f"{minutes}min"
    out["time_bin"] = out["timestamp"].dt.floor(freq)

    agg = (
        out.groupby(
            ["station_id", "station_name_id", "station_name", "location_id", "time_bin"],
            as_index=False
        )
        .agg({
            "n_lends": "sum",
            "n_returns": "sum",
            "latitude": "first",
            "longitude": "first"
        })
        .rename(columns={"time_bin": "hour_ts"})
    )

    agg["total_demand"] = agg["n_lends"] + agg["n_returns"]
    agg["net_flow"] = agg["n_returns"] - agg["n_lends"]
    agg["abs_net_flow"] = agg["net_flow"].abs()

    agg["hour"] = agg["hour_ts"].dt.hour
    agg["dow"] = agg["hour_ts"].dt.dayofweek
    agg["month"] = agg["hour_ts"].dt.month
    agg["is_weekend"] = agg["dow"].isin([5, 6]).astype(int)

    agg["hour_sin"] = np.sin(2 * np.pi * agg["hour"] / 24)
    agg["hour_cos"] = np.cos(2 * np.pi * agg["hour"] / 24)
    agg["dow_sin"]  = np.sin(2 * np.pi * agg["dow"] / 7)
    agg["dow_cos"]  = np.cos(2 * np.pi * agg["dow"] / 7)
    agg["month_sin"] = np.sin(2 * np.pi * (agg["month"] - 1) / 12)
    agg["month_cos"] = np.cos(2 * np.pi * (agg["month"] - 1) / 12)

    agg = agg.sort_values(["station_id", "hour_ts"]).reset_index(drop=True)
    return agg

# %%
# ══════════════════════════════════════════════════════════════
# 2 — Gap-Fill
# ══════════════════════════════════════════════════════════════
def fill_missing_time_bins(x: pd.DataFrame, minutes: int = 60) -> pd.DataFrame:
    freq = f"{minutes}min"
    parts = []
    x = x.copy().sort_values(["station_id", "hour_ts"])
    x = (
        x.groupby(["station_id", "hour_ts"], as_index=False)
         .agg({
             "station_name_id": "first", "station_name": "first",
             "location_id": "first", "latitude": "first",
             "longitude": "first", "n_lends": "sum", "n_returns": "sum",
         })
    )
    key_cols = ["station_id", "station_name_id", "station_name",
                "location_id", "latitude", "longitude"]

    for sid, g in x.groupby("station_id", sort=False):
        g = g.sort_values("hour_ts").copy()
        full_idx = pd.date_range(g["hour_ts"].min(), g["hour_ts"].max(), freq=freq)
        g = g.set_index("hour_ts").reindex(full_idx)
        g.index.name = "hour_ts"
        g["n_lends"]   = g["n_lends"].fillna(0).astype(int)
        g["n_returns"] = g["n_returns"].fillna(0).astype(int)
        for col in key_cols:
            g[col] = g[col].ffill().bfill()
        parts.append(g.reset_index())

    result = pd.concat(parts, ignore_index=True)
    result["total_demand"] = result["n_lends"] + result["n_returns"]
    result["net_flow"]     = result["n_returns"] - result["n_lends"]
    result["abs_net_flow"] = result["net_flow"].abs()

    result["hour"] = result["hour_ts"].dt.hour
    result["dow"]  = result["hour_ts"].dt.dayofweek
    result["month"] = result["hour_ts"].dt.month
    result["is_weekend"] = result["dow"].isin([5, 6]).astype(int)

    result["hour_sin"]  = np.sin(2 * np.pi * result["hour"] / 24)
    result["hour_cos"]  = np.cos(2 * np.pi * result["hour"] / 24)
    result["dow_sin"]   = np.sin(2 * np.pi * result["dow"] / 7)
    result["dow_cos"]   = np.cos(2 * np.pi * result["dow"] / 7)
    result["month_sin"] = np.sin(2 * np.pi * (result["month"] - 1) / 12)
    result["month_cos"] = np.cos(2 * np.pi * (result["month"] - 1) / 12)

    return result.sort_values(["station_id", "hour_ts"]).reset_index(drop=True)

# %%
# ══════════════════════════════════════════════════════════════
# 3 — Station-Filter, Demand-Regime, Train/Val/Test Split
# ══════════════════════════════════════════════════════════════
def prepare_stations_and_splits(df: pd.DataFrame, cfg, city_name=""):
    n_days = (df["hour_ts"].max() - df["hour_ts"].min()).days + 1
    min_events = int(n_days * cfg.min_events_per_day)

    station_volume = df.groupby("station_id")["total_demand"].sum()
    active_ids = station_volume[station_volume >= min_events].index.tolist()
    df = df[df["station_id"].isin(active_ids)].copy()

    station_profile = (
        df.groupby(["station_id", "station_name"], as_index=False)
          .agg(
              avg_total_demand_h=("total_demand", "mean"),
              avg_lends_h=("n_lends", "mean"),
              avg_returns_h=("n_returns", "mean"),
              latitude=("latitude", "first"),
              longitude=("longitude", "first")
          )
    )
    q1 = station_profile["avg_total_demand_h"].quantile(cfg.low_demand_q)
    q2 = station_profile["avg_total_demand_h"].quantile(cfg.high_demand_q)
    station_profile["demand_regime"] = station_profile["avg_total_demand_h"].apply(
        lambda x: "low" if x <= q1 else ("mid" if x <= q2 else "high")
    )
    df = df.merge(
        station_profile[["station_id", "demand_regime", "avg_total_demand_h"]],
        on="station_id", how="left"
    )

    t_min = df["hour_ts"].min()
    t_max = df["hour_ts"].max()
    total_h = (t_max - t_min).total_seconds() / 3600

    train_end = t_min + pd.Timedelta(hours=int(total_h * cfg.train_ratio))
    val_end   = t_min + pd.Timedelta(hours=int(total_h * cfg.val_ratio))

    cn = f" ({city_name})" if city_name else ""
    print(f"  Aktive Stationen{cn}: {df['station_id'].nunique()}")
    print(f"  Regime: {station_profile['demand_regime'].value_counts().to_dict()}")
    print(f"  Zeitraum: {t_min.date()} bis {t_max.date()} ({n_days} Tage)")
    print(f"  Split: Train < {train_end.date()}, Val < {val_end.date()}, Test ab {val_end.date()}")

    return df, station_profile, train_end, val_end

# %%
# ══════════════════════════════════════════════════════════════
# 4 — Rolling Context z-Scores + Poisson + ECDF + Labels
# ══════════════════════════════════════════════════════════════
TARGETS = ["n_lends", "n_returns", "net_flow", "total_demand"]
COUNT_TARGETS = ["n_lends", "n_returns", "total_demand"]

def add_context_keys(x: pd.DataFrame) -> pd.DataFrame:
    x = x.copy()
    x["ctx_hour"] = x["hour_ts"].dt.hour
    x["ctx_dow"]  = x["hour_ts"].dt.dayofweek
    return x

def rolling_context_scores_vectorized(
    full_df: pd.DataFrame, target: str,
    rolling_days: int = 56, min_obs: int = 20
) -> pd.DataFrame:
    x = full_df.copy().sort_values(["station_id", "hour_ts"]).reset_index(drop=True)
    mu_col    = f"{target}_mu_ctx_roll"
    sd_col    = f"{target}_sd_ctx_roll"
    score_col = f"{target}_z_ctx_roll"

    n_slots = max(rolling_days // 7, 4)
    main_window = n_slots
    main_minp   = min(min_obs, main_window)

    grouped = x.groupby(["station_id", "ctx_hour", "ctx_dow"])[target]
    rolling_mean = grouped.transform(
        lambda s: s.shift(1).rolling(window=main_window, min_periods=main_minp).mean()
    )
    rolling_std = grouped.transform(
        lambda s: s.shift(1).rolling(window=main_window, min_periods=main_minp).std(ddof=0)
    )

    fb1_window = n_slots * 2
    fb1_minp   = min(min_obs, fb1_window)
    grouped_sh = x.groupby(["station_id", "ctx_hour"])[target]
    fb1_mean = grouped_sh.transform(
        lambda s: s.shift(1).rolling(window=fb1_window, min_periods=fb1_minp).mean()
    )
    fb1_std = grouped_sh.transform(
        lambda s: s.shift(1).rolling(window=fb1_window, min_periods=fb1_minp).std(ddof=0)
    )

    fb2_window = n_slots * 4
    fb2_minp   = min(min_obs, fb2_window)
    grouped_s = x.groupby(["station_id"])[target]
    fb2_mean = grouped_s.transform(
        lambda s: s.shift(1).rolling(window=fb2_window, min_periods=fb2_minp).mean()
    )
    fb2_std = grouped_s.transform(
        lambda s: s.shift(1).rolling(window=fb2_window, min_periods=fb2_minp).std(ddof=0)
    )

    mu = rolling_mean.copy()
    sd = rolling_std.copy()
    mask1 = mu.isna()
    mu = mu.where(~mask1, fb1_mean)
    sd = sd.where(~mask1, fb1_std)
    mask2 = mu.isna()
    mu = mu.where(~mask2, fb2_mean)
    sd = sd.where(~mask2, fb2_std)
    sd = sd.clip(lower=1e-6)
    z = (x[target] - mu) / sd

    x[mu_col]    = mu
    x[sd_col]    = sd
    x[score_col] = z
    return x


def add_rolling_poisson_scores_vectorized(
    full_df: pd.DataFrame, target: str,
    rolling_days: int = 56, min_obs: int = 20
) -> pd.DataFrame:
    x = full_df.copy().sort_values(["station_id", "hour_ts"]).reset_index(drop=True)
    lam_col       = f"{target}_lambda_ctx_roll"
    score_col     = f"{target}_poisson_upper_score"
    score_low_col = f"{target}_poisson_lower_score"
    mu_col        = f"{target}_mu_ctx_roll"

    if mu_col not in x.columns:
        raise ValueError(f"{mu_col} muss zuerst berechnet werden")

    x[lam_col] = x[mu_col].clip(lower=1e-6)
    vals = x[target].values
    lams = x[lam_col].values

    with np.errstate(divide='ignore', invalid='ignore'):
        tail_p = poisson.sf(vals.astype(float) - 1, lams.astype(float))
        score  = -np.log10(np.clip(tail_p, 1e-12, None))
        lower_p   = poisson.cdf(vals.astype(float), lams.astype(float))
        score_low = -np.log10(np.clip(lower_p, 1e-12, None))

    mask_nan = np.isnan(lams)
    score[mask_nan]     = np.nan
    score_low[mask_nan] = np.nan

    x[score_col]     = score
    x[score_low_col] = score_low
    return x


def percentile_score(train_vals: np.ndarray, values: np.ndarray) -> np.ndarray:
    train_vals = np.asarray(train_vals, dtype=float)
    values     = np.asarray(values, dtype=float)
    train_vals = train_vals[np.isfinite(train_vals)]
    if len(train_vals) == 0:
        return np.full(len(values), np.nan, dtype=float)
    train_sorted = np.sort(train_vals)
    ranks = np.searchsorted(train_sorted, values, side="right")
    return ranks / len(train_sorted)


def run_statistical_pipeline(df, cfg, train_end):
    df = add_context_keys(df)
    for t in TARGETS:
        df = rolling_context_scores_vectorized(df, t, cfg.rolling_days, cfg.min_context_obs)
    for t in COUNT_TARGETS:
        df = add_rolling_poisson_scores_vectorized(df, t, cfg.rolling_days, cfg.min_context_obs)

    train_mask = df["hour_ts"] < train_end
    score_cols = [c for c in df.columns if c.endswith("_z_ctx_roll")]

    for c in score_cols:
        train_vals = df.loc[train_mask, c].dropna().values
        df[f"{c}_ecdf"] = percentile_score(train_vals, df[c].values)

    def label_row(row):
        for t in TARGETS:
            z_col = f"{t}_z_ctx_roll"
            if z_col in row.index and pd.notna(row[z_col]):
                if row[z_col] >= 3.0:
                    return "anomal_high"
                if row[z_col] <= -3.0:
                    return "anomal_low"
        return "normal"

    df["label_eval"] = df.apply(label_row, axis=1)
    return df

# %%
# ══════════════════════════════════════════════════════════════
# 5 — Sequenzbuilder (Window-Level Labels)
# ══════════════════════════════════════════════════════════════
def make_sequences_with_window_labels(
    x: pd.DataFrame, feature_cols: List[str], window_size: int,
    synth_label_col: str = "synth_label",
    synth_type_col: str = "synth_type",
    require_contiguous: bool = True,
    agg_minutes: int = 60
) -> Tuple[np.ndarray, pd.DataFrame]:
    X_parts, meta_parts = [], []
    expected_ns = pd.Timedelta(minutes=agg_minutes).value

    for sid, g in x.groupby("station_id", sort=False):
        g = g.sort_values("hour_ts").reset_index(drop=True)
        n = len(g)
        if n < window_size:
            continue

        vals = g[feature_cols].to_numpy(dtype=np.float32)
        win  = sliding_window_view(vals, window_shape=window_size, axis=0)
        win  = np.moveaxis(win, -1, 1)

        valid_mask = np.ones(n - window_size + 1, dtype=bool)

        if require_contiguous:
            ts_int = pd.to_datetime(g["hour_ts"]).astype("int64").to_numpy()
            diffs  = np.diff(ts_int)
            step_ok = (diffs == expected_ns).astype(np.int8)
            if window_size > 1:
                ok_sums = np.convolve(step_ok, np.ones(window_size-1, dtype=np.int32), mode="valid")
                valid_mask = (ok_sums == (window_size - 1))

        if not valid_mask.any():
            continue

        end_indices = np.arange(window_size - 1, n)[valid_mask]
        X_parts.append(win[valid_mask])

        meta_chunk = g.iloc[end_indices].copy()

        synth_arr = g[synth_label_col].to_numpy()
        type_arr  = g[synth_type_col].to_numpy()

        window_labels, window_types, window_counts = [], [], []
        for end_idx in end_indices:
            start_idx = end_idx - window_size + 1
            window_synth = synth_arr[start_idx:end_idx + 1]
            window_type  = type_arr[start_idx:end_idx + 1]

            has_synth = int(window_synth.max())
            n_synth   = int(window_synth.sum())

            if has_synth:
                synth_positions = np.where(window_synth == 1)[0]
                wtype = window_type[synth_positions[-1]]
            else:
                wtype = "none"

            window_labels.append(has_synth)
            window_types.append(wtype)
            window_counts.append(n_synth)

        meta_chunk["window_synth_label"] = window_labels
        meta_chunk["window_synth_type"]  = window_types
        meta_chunk["n_synth_in_window"]  = window_counts
        meta_parts.append(meta_chunk)

    if X_parts:
        X    = np.concatenate(X_parts, axis=0)
        meta = pd.concat(meta_parts, axis=0).reset_index(drop=True)
    else:
        X    = np.empty((0, window_size, len(feature_cols)), dtype=np.float32)
        meta = pd.DataFrame()

    return X, meta

# %%
# ══════════════════════════════════════════════════════════════
# 6 — Model Builders (AE + Forecaster)
# ══════════════════════════════════════════════════════════════
def build_lstm_autoencoder(
    n_input_features: int,
    window_size: int,
    latent_dim: int = 32,
    n_layers: int = 2,
    dropout: float = 0.1,
    bidirectional: bool = False,
    n_output_features: Optional[int] = None,
) -> keras.Model:
    n_output_features = n_output_features or n_input_features
    inputs = keras.Input(shape=(window_size, n_input_features), name="encoder_input")
    x = inputs
    for i in range(n_layers):
        return_sequences = (i < n_layers - 1)
        lstm = layers.LSTM(
            latent_dim, return_sequences=return_sequences,
            dropout=dropout, name=f"encoder_lstm_{i+1}"
        )
        x = layers.Bidirectional(lstm, name=f"encoder_bi_{i+1}")(x) if bidirectional else lstm(x)
    latent = x
    x = layers.RepeatVector(window_size, name="repeat_vector")(latent)
    for i in range(n_layers):
        lstm = layers.LSTM(
            latent_dim, return_sequences=True,
            dropout=dropout, name=f"decoder_lstm_{i+1}"
        )
        x = layers.Bidirectional(lstm, name=f"decoder_bi_{i+1}")(x) if bidirectional else lstm(x)
    outputs = layers.TimeDistributed(
        layers.Dense(n_output_features), name="output_dense"
    )(x)
    return keras.Model(inputs, outputs, name="lstm_autoencoder")


def build_lstm_forecaster(
    n_input_features: int,
    n_output_features: int,
    context_steps: int = 23,
    latent_dim: int = 32,
    n_layers: int = 2,
    dropout: float = 0.1,
) -> keras.Model:
    inputs = keras.Input(shape=(context_steps, n_input_features), name="forecast_input")
    x = inputs
    for i in range(n_layers):
        return_sequences = (i < n_layers - 1)
        x = layers.LSTM(
            latent_dim, return_sequences=return_sequences,
            dropout=dropout, name=f"forecast_lstm_{i+1}"
        )(x)
    outputs = layers.Dense(n_output_features, name="forecast_output")(x)
    return keras.Model(inputs, outputs, name="lstm_forecaster")


def train_model_generic(model, X_train, Y_train, X_val, Y_val,
                        epochs, lr, batch_size, early_stop, verbose=1):
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr, clipnorm=1.0),
        loss="mse"
    )
    callbacks = [
        keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=early_stop,
            restore_best_weights=True, verbose=1
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=4, verbose=1
        )
    ]
    history = model.fit(
        X_train, Y_train,
        validation_data=(X_val, Y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=verbose
    )
    return model, history

# %%
def train_model_fixed_epochs(model, X_train, Y_train, epochs, lr, batch_size, verbose=1):
    """Training mit fixer Epochenzahl. Kein Val-Set, kein Early Stopping. CosineDecay LR."""
    lr_schedule = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=lr,
        decay_steps=epochs * max(1, len(X_train) // batch_size),
        alpha=1e-6
    )
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=1.0), loss="mse")
    history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=verbose)
    return model, {k: [float(v) for v in vals] for k, vals in history.history.items()}

# %%
# ══════════════════════════════════════════════════════════════
# 7 — Scoring Helpers (AE + Forecaster)
# ══════════════════════════════════════════════════════════════
def predict_in_batches(model, X, batch_size=2048):
    preds = []
    for i in range(0, len(X), batch_size):
        preds.append(model.predict(X[i:i + batch_size], verbose=0))
    return np.concatenate(preds, axis=0) if preds else np.empty((0, 0, 0), dtype=np.float32)


def compute_reconstruction_scores(X, X_hat, input_features, score_features,
                                  mode="last_step_mean"):
    score_idx = [input_features.index(c) for c in score_features]
    err = (X - X_hat) ** 2
    err_score = err[:, :, score_idx]
    if mode == "last_step_mean":
        return err_score[:, -1, :].mean(axis=1)
    elif mode == "window_mean":
        return err_score.mean(axis=(1, 2))
    elif mode == "max_over_features":
        return err_score[:, -1, :].max(axis=1)
    else:
        raise ValueError(f"Unbekannter mode: {mode}")


def compute_forecast_scores(model, X_input, X_actual_last_step, score_features,
                            ae_features, mode="directional"):
    X_pred = predict_in_batches(model, X_input, batch_size=2048)
    score_idx = [ae_features.index(f) for f in score_features]
    X_actual = X_actual_last_step[:, score_idx]
    err = (X_pred - X_actual) ** 2
    if mode == "mean":
        return err.mean(axis=1)
    elif mode == "max":
        return err.max(axis=1)
    elif mode == "directional":
        abs_err = np.abs(X_pred - X_actual)
        denom = np.maximum(np.maximum(np.abs(X_actual), np.abs(X_pred)), 1e-6)
        rel_err = abs_err / denom
        return 0.5 * abs_err.mean(axis=1) + 0.5 * rel_err.mean(axis=1)
    else:
        raise ValueError(f"Unbekannter mode: {mode}")

# %%
# ══════════════════════════════════════════════════════════════
# 8 — Z-Normalisierung (Hour + Hour×Station)
# ══════════════════════════════════════════════════════════════
def znorm_score_by_hour(meta_df, raw_score_col, val_start, test_start,
                        new_col="score_znorm_hour"):
    meta = meta_df.copy()
    val_normal = (
        (meta["hour_ts"] >= val_start) &
        (meta["hour_ts"] < test_start) &
        (meta["synth_label"] == 0)
    )
    hour_col = meta["hour_ts"].dt.hour
    mu_per_hour = {}
    std_per_hour = {}
    for h in range(24):
        vals = meta.loc[val_normal & (hour_col == h), raw_score_col].dropna()
        mu_per_hour[h]  = vals.mean() if len(vals) > 0 else 0.0
        std_per_hour[h] = vals.std()  if len(vals) > 1 else 1.0

    hours = hour_col.values
    raw   = meta[raw_score_col].values
    znorm = np.zeros_like(raw)
    for i in range(len(raw)):
        h = hours[i]
        znorm[i] = (raw[i] - mu_per_hour[h]) / max(std_per_hour[h], 1e-8)
    meta[new_col] = znorm
    return meta, mu_per_hour, std_per_hour


def znorm_score_by_hour_station(meta_df, raw_score_col, val_start, test_start,
                                new_col="score_znorm_hour_station"):
    meta = meta_df.copy()
    val_normal = (
        (meta["hour_ts"] >= val_start) &
        (meta["hour_ts"] < test_start) &
        (meta["synth_label"] == 0)
    )
    hour_col = meta["hour_ts"].dt.hour
    meta["_hour_tmp"] = hour_col

    stats = (
        meta[val_normal]
        .groupby(["station_id", "_hour_tmp"])[raw_score_col]
        .agg(["mean", "std", "count"])
        .reset_index()
    )
    global_stats = (
        meta[val_normal]
        .groupby("_hour_tmp")[raw_score_col]
        .agg(["mean", "std"])
        .reset_index()
        .rename(columns={"mean": "g_mean", "std": "g_std"})
    )
    stats = stats.merge(global_stats, on="_hour_tmp", how="left")
    stats["use_mean"] = np.where(stats["count"] >= 10, stats["mean"], stats["g_mean"])
    stats["use_std"]  = np.where(stats["count"] >= 10, stats["std"],  stats["g_std"])
    stats["use_std"]  = stats["use_std"].clip(lower=1e-8)

    meta = meta.merge(
        stats[["station_id", "_hour_tmp", "use_mean", "use_std"]],
        on=["station_id", "_hour_tmp"], how="left"
    )
    meta["use_mean"] = meta["use_mean"].fillna(0.0)
    meta["use_std"]  = meta["use_std"].fillna(1.0).clip(lower=1e-8)
    meta[new_col] = (meta[raw_score_col] - meta["use_mean"]) / meta["use_std"]
    meta = meta.drop(columns=["_hour_tmp", "use_mean", "use_std"])
    return meta

# %%
# ══════════════════════════════════════════════════════════════
# 9 — Synthetic Injection (V17b: Spike Only)
# ══════════════════════════════════════════════════════════════
V17B_INJECTION_PROBS = {
    "point_spike": 1.0
}
V17B_COLLECTIVE_BLOCK_LEN = (2, 4)

def inject_synthetic_anomalies_v17b(
    df: pd.DataFrame,
    inject_start: pd.Timestamp,
    injection_rate: float = 0.015,
    seed: int = 42,
    verbose: bool = True
) -> pd.DataFrame:
    probs = list(V17B_INJECTION_PROBS.values())
    type_names = list(V17B_INJECTION_PROBS.keys())
    block_min, block_max = V17B_COLLECTIVE_BLOCK_LEN

    rng = np.random.RandomState(seed)
    out = df.copy()

    out["original_n_lends"]   = out["n_lends"].copy()
    out["original_n_returns"] = out["n_returns"].copy()
    out["synth_label"] = 0
    out["synth_type"]  = "none"

    inject_mask = out["hour_ts"] >= inject_start
    inject_idx  = out[inject_mask].index.to_numpy()

    if len(inject_idx) == 0:
        print("  WARNUNG: Keine Daten ab inject_start!")
        return out

    n_inject = max(1, int(len(inject_idx) * injection_rate))
    inject_df = out.loc[inject_idx]
    has_demand = inject_df[inject_df["total_demand"] > 0].index.to_numpy()

    if len(has_demand) < n_inject:
        n_inject = len(has_demand)

    chosen_idx = rng.choice(has_demand, size=n_inject, replace=False)
    types = rng.choice(type_names, size=n_inject, p=probs)

    injected_indices = set()
    requested_counts = {t: 0 for t in type_names}
    injected_counts  = {t: 0 for t in type_names}

    for idx, anom_type in zip(chosen_idx, types):
        requested_counts[anom_type] += 1
        if idx in injected_indices:
            continue

        row = out.loc[idx]

        if anom_type == "point_spike":
            factor = rng.uniform(2.0, 4.0)
            out.loc[idx, "n_lends"]   = int(row["n_lends"] * factor) + rng.randint(1, 4)
            out.loc[idx, "n_returns"] = int(row["n_returns"] * factor) + rng.randint(1, 4)
            out.loc[idx, "synth_label"] = 1
            out.loc[idx, "synth_type"]  = "point_spike"
            injected_indices.add(idx)
            injected_counts["point_spike"] += 1

    out.loc[list(injected_indices), "total_demand"] = (
        out.loc[list(injected_indices), "n_lends"] +
        out.loc[list(injected_indices), "n_returns"]
    )

    if verbose:
        print(f"  Injection: requested={sum(requested_counts.values())}, "
              f"injected={sum(injected_counts.values())}")
        for t in type_names:
            print(f"    {t}: req={requested_counts[t]}, inj={injected_counts[t]}")

    return out

# %% [markdown]
# ---
# ## City Data Pipeline + Evaluation (Exp0: ohne Wetter-Merge)

# %%
# ══════════════════════════════════════════════════════════════
# 10 — City Data Pipeline (Exp0: ohne Wetter-Merge)
# ══════════════════════════════════════════════════════════════
# ANPASSUNG gegenüber V22b: Wetter-Parameter und Wetter-Merge entfernt,
# da Exp0 nur das Baseline-Feature-Set (demand + zyklisch) verwendet.
# Alle anderen Schritte sind identisch.

def prepare_city_data(demand_path: str, geo_path: str, station_names_path: str,
                      cfg, city_name: str):
    print(f"\n{'='*70}")
    print(f"  DATEN-PIPELINE: {city_name}")
    print(f"{'='*70}")

    demand = pd.read_parquet(demand_path)
    geo    = pd.read_parquet(geo_path)
    snames = pd.read_parquet(station_names_path)
    snames = snames.rename(columns={'id': 'station_name_id', 'name': 'station_name'})

    demand = demand.merge(snames[['station_name_id', 'station_name']], on='station_name_id', how='left')
    demand = demand.merge(geo[['location_id', 'latitude', 'longitude']], on='location_id', how='left')
    demand['timestamp'] = pd.to_datetime(demand['timestamp'], utc=True)

    print(f"  Roh: {len(demand):,} Zeilen, {demand['station_id'].nunique()} Stationen")
    print(f"  Zeitraum: {demand['timestamp'].min().date()} bis {demand['timestamp'].max().date()}")

    print("\n  [1] Aggregation...")
    df = aggregate_station_level(demand, minutes=cfg.aggregation_minutes)
    print(f"      Shape: {df.shape}")

    print("  [2] Gap-Fill...")
    n_before = len(df)
    df = fill_missing_time_bins(df, minutes=cfg.aggregation_minutes)
    print(f"      {n_before:,} -> {len(df):,} (+{len(df)-n_before:,})")

    print("  [3] Stationen, Regime, Splits...")
    df, station_profile, train_end, val_end = prepare_stations_and_splits(df, cfg, city_name)

    print("  [4] Statistische Scoring-Pipeline...")
    df = run_statistical_pipeline(df, cfg, train_end)

    return df, station_profile, train_end, val_end

# %%
# ══════════════════════════════════════════════════════════════
# 11 — V17b Unified Evaluation
# ══════════════════════════════════════════════════════════════
ANOM_TYPES = ["point_spike"]
REGIMES    = ["high", "mid", "low"]

def evaluate_v17b(
    meta: pd.DataFrame,
    score_col: str,
    experiment_name: str,
    val_start: pd.Timestamp,
    test_start: pd.Timestamp,
    verbose: bool = True
) -> Dict:
    meta = meta.copy()
    meta["split_eval"] = np.where(
        meta["hour_ts"] < val_start, "train",
        np.where(meta["hour_ts"] < test_start, "val", "test")
    )

    val_m  = meta[meta["split_eval"] == "val"].copy()
    test_m = meta[meta["split_eval"] == "test"].copy()

    if len(val_m) == 0 or len(test_m) == 0:
        print(f"  [{experiment_name}] WARNUNG: Keine VAL/TEST-Daten!")
        return {}

    results = {"experiment": experiment_name, "n_val": len(val_m), "n_test": len(test_m)}

    n_test_total = len(test_m)
    n_test_anom  = (test_m["synth_label"] == 1).sum()
    results["anomaly_rate_total"] = n_test_anom / n_test_total
    results["n_test_anom"] = int(n_test_anom)

    for atype in ANOM_TYPES:
        n_t = (test_m["synth_type"] == atype).sum()
        results[f"rate_{atype}"] = n_t / n_test_total
        results[f"n_{atype}"] = int(n_t)

    # Threshold via VAL
    y_val = val_m["synth_label"].astype(int).values
    s_val = val_m[score_col].values
    threshold = None
    if len(np.unique(y_val)) > 1:
        prec_v, rec_v, thr_v = precision_recall_curve(y_val, s_val)
        results["val_pr_auc"] = average_precision_score(y_val, s_val)
        if len(thr_v) > 0:
            f1_v = 2 * prec_v[:-1] * rec_v[:-1] / (prec_v[:-1] + rec_v[:-1] + 1e-12)
            best_idx = np.argmax(f1_v)
            threshold = float(thr_v[best_idx])
            results["val_best_f1"] = float(f1_v[best_idx])
            results["val_threshold"] = threshold

    if threshold is None:
        val_norm = val_m[val_m["synth_label"] == 0][score_col]
        threshold = float(val_norm.quantile(0.99)) if len(val_norm) > 0 else float(test_m[score_col].quantile(0.99))
        results["val_threshold"] = threshold
        results["threshold_source"] = "fallback_99pct"

    # TEST Metriken
    y_test = test_m["synth_label"].astype(int).values
    s_test = test_m[score_col].values
    p_test = (s_test >= threshold).astype(int)

    if len(np.unique(y_test)) > 1:
        results["test_pr_auc"]  = average_precision_score(y_test, s_test)
        results["test_roc_auc"] = roc_auc_score(y_test, s_test)
        results["test_f1"]      = f1_score(y_test, p_test, zero_division=0)
        results["test_prec"]    = precision_score(y_test, p_test, zero_division=0)
        results["test_recall"]  = recall_score(y_test, p_test, zero_division=0)

    for atype in ANOM_TYPES:
        type_mask = test_m["synth_type"] == atype
        normal_mask = test_m["synth_label"] == 0
        sub = test_m[type_mask | normal_mask].copy()
        n_anom = int(type_mask.sum())
        if n_anom > 0 and len(sub) > 0:
            y_t = (sub["synth_type"] == atype).astype(int).values
            y_s = sub[score_col].values
            if len(set(y_t)) > 1:
                results[f"pr_{atype}"] = average_precision_score(y_t, y_s)
            detected = (test_m.loc[type_mask, score_col] >= threshold).sum()
            results[f"dr_{atype}"] = detected / n_anom
        else:
            results[f"pr_{atype}"] = None
            results[f"dr_{atype}"] = None

    # Regime × Type
    regime_rows = []
    for atype in ANOM_TYPES:
        for regime in REGIMES:
            rm = test_m["demand_regime"] == regime
            tm = test_m["synth_type"] == atype
            nm = test_m["synth_label"] == 0
            n_a = int((rm & tm).sum())
            n_n = int((rm & nm).sum())
            pr, f1_val, dr = None, None, None
            if n_a > 0 and n_n > 0:
                sub = test_m[(rm & tm) | (rm & nm)]
                y_t = (sub["synth_type"] == atype).astype(int).values
                y_s = sub[score_col].values
                pr = average_precision_score(y_t, y_s) if len(set(y_t)) > 1 else None
                p_sub = (y_s >= threshold).astype(int)
                f1_val = f1_score(y_t, p_sub, zero_division=0)
                detected = (test_m[rm & tm][score_col] >= threshold).sum()
                dr = detected / n_a
            regime_rows.append({
                "type": atype, "regime": regime,
                "n_anom": n_a, "pr_auc": pr, "f1": f1_val, "dr": dr
            })
    results["regime_detail"] = pd.DataFrame(regime_rows)

    if verbose:
        print(f"\n  [{experiment_name}]")
        print(f"    TEST PR-AUC={results.get('test_pr_auc', 'N/A'):.4f}, "
              f"F1={results.get('test_f1', 'N/A'):.4f}, "
              f"Prec={results.get('test_prec', 'N/A'):.4f}, "
              f"Recall={results.get('test_recall', 'N/A'):.4f}")

    return results

# %% [markdown]
# ---
# ## Exp0 — City Discovery + Oracle-Loop

# %%
# ══════════════════════════════════════════════════════════════
# MC-1 — City Discovery
# ══════════════════════════════════════════════════════════════
import re
from pathlib import Path

def city_to_key(city_name: str) -> str:
    return re.sub(r"[^a-z0-9]+", "_", city_name.lower()).strip("_")

def discover_city_demand_paths(cleaned_base: str):
    demand_root = Path(cleaned_base) / "demand"
    city_map = {}
    if not demand_root.exists():
        print(f"WARNUNG: demand_root nicht gefunden: {demand_root}")
        return city_map
    for city_dir in sorted(demand_root.iterdir()):
        if not city_dir.is_dir():
            continue
        p = city_dir / "demand_cleaned.parquet"
        if p.exists():
            city_map[city_dir.name] = str(p)
    return city_map

DISCOVERED_CITY_DEMAND = discover_city_demand_paths(CLEANED_BASE)
CITY_DEMAND_ALL = {**DISCOVERED_CITY_DEMAND, **CITY_DEMAND}

print(f"Gefundene Städte: {len(CITY_DEMAND_ALL)}")

# ── Zielstädte (hier anpassen) ──────────────────────────────
TARGET_CITIES = [
    "bochum",
    "braunschweig",
    "dortmund",
    "duisburg",
    "essen",
    "freiburg",
    "gießen",
    "heidelberg",
    "kaiserslautern",
    "kassel",
    "leverkusen",
    "ludwigshafen",
    "mannheim",
    "marburg",
    "offenburg",
    "wiesbaden",
    "winsen (Luhe)",
]

TARGET_CITIES = [c for c in TARGET_CITIES if c in CITY_DEMAND_ALL]
print("\nTarget Cities:", TARGET_CITIES)
# Out:
# Gefundene Städte: 34
#
# Target Cities: ['bochum', 'braunschweig', 'dortmund', 'duisburg', 'essen', 'freiburg', 'gießen', 'heidelberg', 'kaiserslautern', 'kassel', 'leverkusen', 'ludwigshafen', 'mannheim', 'marburg', 'offenburg', 'wiesbaden', 'winsen (Luhe)']

# %%
# ══════════════════════════════════════════════════════════════
# MC-2 — Speicherung + Flatten Helpers
# ══════════════════════════════════════════════════════════════
def save_window_level_scores(meta, city_name, model_name, out_dir,
                             score_cols=None, extra_cols=None):
    score_cols = score_cols or []
    extra_cols = extra_cols or []
    base_cols = [
        "station_id", "hour_ts", "split_eval", "label_eval",
        "synth_label", "synth_type", "demand_regime"
    ]
    cols = [c for c in base_cols + score_cols + extra_cols if c in meta.columns]
    out = meta[cols].copy()
    out["city"] = city_name
    out["city_key"] = city_to_key(city_name)
    out["model"] = model_name

    fpath = f"{out_dir}/{city_to_key(city_name)}__{model_name}__window_scores.parquet"
    out.to_parquet(fpath, index=False)
    print(f"  Gespeichert: {fpath} | rows={len(out):,}")
    return fpath

def flatten_result_dict(d: dict, city_name: str, model_name: str):
    row = {}
    for k, v in d.items():
        if isinstance(v, pd.DataFrame):
            continue
        row[k] = v
    row["city"] = city_name
    row["city_key"] = city_to_key(city_name)
    row["model"] = model_name
    return row

def add_station_demand_weight(meta: pd.DataFrame):
    meta = meta.copy()
    demand_col = next((c for c in ["original_n_lends", "n_lends"] if c in meta.columns), None)
    if demand_col is None:
        stat = meta.groupby("station_id").size().rename("station_activity_raw").reset_index()
    else:
        stat = (
            meta.groupby("station_id")[demand_col]
                .mean()
                .rename("station_activity_raw")
                .reset_index()
        )
    stat["station_activity_log1p"] = np.log1p(stat["station_activity_raw"].clip(lower=0))
    q33 = stat["station_activity_raw"].quantile(0.33)
    q67 = stat["station_activity_raw"].quantile(0.67)
    stat["station_activity_group"] = np.where(
        stat["station_activity_raw"] <= q33, "low",
        np.where(stat["station_activity_raw"] >= q67, "high", "medium")
    )
    meta = meta.merge(stat, on="station_id", how="left")
    return meta

# %%
# ══════════════════════════════════════════════════════════════
# MC-3a — Sequenz-Erstellung
# ══════════════════════════════════════════════════════════════
from sklearn.preprocessing import StandardScaler

def build_sequences_for_city(
    df_clean, df_inj, train_end, val_end, city_name, scaler_ext=None
):
    """
    Generische Sequenz-Erstellung pro Stadt.
    Liest ae_features und score_features aus dem globalen Scope.
    """
    global ae_features, score_features, context_steps

    df_c = df_clean.copy().sort_values(["station_id", "hour_ts"]).reset_index(drop=True)
    df_inj_s = df_inj.copy().sort_values(["station_id", "hour_ts"]).reset_index(drop=True)

    df_c["hour_ts"] = pd.to_datetime(df_c["hour_ts"], utc=True)
    df_inj_s["hour_ts"] = pd.to_datetime(df_inj_s["hour_ts"], utc=True)
    train_end = pd.to_datetime(train_end, utc=True)
    val_end   = pd.to_datetime(val_end, utc=True)

    # Prüfe ob alle Features vorhanden
    missing = [f for f in ae_features if f not in df_c.columns]
    if missing:
        print(f"  [{city_name}] WARNUNG: Fehlende Features: {missing}")
        return None

    df_c = df_c.dropna(subset=ae_features)
    df_inj_s = df_inj_s.dropna(subset=ae_features)

    train_mask_sc = df_c["hour_ts"] < train_end
    if scaler_ext is None:
        scaler = StandardScaler()
        scaler.fit(df_c.loc[train_mask_sc, ae_features])
        print(f"  [{city_name}] Scaler gefittet auf {train_mask_sc.sum():,} Train-Zeilen ({len(ae_features)} Features)")
    else:
        scaler = scaler_ext

    df_inj_scaled = df_inj_s.copy()
    df_inj_scaled.loc[:, ae_features] = scaler.transform(df_inj_s[ae_features])

    meta_cols_to_keep = [
        "synth_label", "synth_type", "original_n_lends", "original_n_returns",
        "demand_regime", "label_eval", "station_id", "hour_ts", "n_lends", "n_returns",
    ]
    for col in meta_cols_to_keep:
        if col in df_inj_s.columns:
            df_inj_scaled[col] = df_inj_s[col].values

    X_all, meta_all = make_sequences_with_window_labels(
        df_inj_scaled,
        feature_cols=ae_features,
        window_size=cfg.ae_window_size,
        synth_label_col="synth_label",
        synth_type_col="synth_type",
        require_contiguous=cfg.require_contiguous,
        agg_minutes=cfg.aggregation_minutes
    )

    if "hour_ts" in meta_all.columns:
        meta_all["hour_ts"] = pd.to_datetime(meta_all["hour_ts"], utc=True)

    meta_all["split_eval"] = np.where(
        meta_all["hour_ts"] < train_end, "train",
        np.where(meta_all["hour_ts"] < val_end, "val", "test")
    )

    print(f"  [{city_name}] Sequenzen: {X_all.shape}")
    print(f"  [{city_name}] Split: {meta_all['split_eval'].value_counts().to_dict()}")

    train_normal = (meta_all["split_eval"] == "train") & (meta_all["label_eval"] == "normal")
    val_normal = (
        (meta_all["split_eval"] == "val") &
        (meta_all["synth_label"] == 0) &
        (meta_all["label_eval"] == "normal")
    )
    X_train = X_all[train_normal.values]
    X_val_c = X_all[val_normal.values]

    print(f"  [{city_name}] X_train (normal): {X_train.shape}, X_val (normal): {X_val_c.shape}")

    return {
        "X_all": X_all, "meta_all": meta_all, "scaler": scaler,
        "X_train": X_train, "X_val_clean": X_val_c,
        "train_normal_mask": train_normal, "val_normal_mask": val_normal,
        "train_end": train_end, "val_end": val_end,
    }

# %%
# ══════════════════════════════════════════════════════════════
# 0c — Config (Exp3: Single-Source Pre-Train + Fine-Tune)
# ══════════════════════════════════════════════════════════════
DATA_BASE    = '/content/drive/MyDrive/BA_Colab/data'
CLEANED_BASE = '/content/drive/MyDrive/BA_Colab/cleaned'

RUN_NAME    = 'exp03_finetune_pairs_new_pairs'

RESULTS_DIR = f'{DATA_BASE}/{RUN_NAME}'
MODELS_DIR  = f'{RESULTS_DIR}/models'

# Quelle der Exp01-Oracle-Modelle
SOURCE_RUN_NAME   = 'exp01_oracle_scarcity'
SOURCE_MODELS_DIR = f'{DATA_BASE}/{SOURCE_RUN_NAME}/models'

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)

geo_path           = f'{CLEANED_BASE}/geo_information/geo_information.parquet'
station_names_path = f'{DATA_BASE}/station_names/station_names.parquet'

CITY_DEMAND = {
    "bochum":        f"{CLEANED_BASE}/demand/Bochum/demand_cleaned.parquet",
    "braunschweig":  f"{CLEANED_BASE}/demand/Braunschweig/demand_cleaned.parquet",
    "dortmund":      f"{CLEANED_BASE}/demand/Dortmund/demand_cleaned.parquet",
    "duisburg":      f"{CLEANED_BASE}/demand/Duisburg/demand_cleaned.parquet",
    "essen":         f"{CLEANED_BASE}/demand/Essen/demand_cleaned.parquet",
    "freiburg":      f"{CLEANED_BASE}/demand/Freiburg/demand_cleaned.parquet",
    "gießen":        f"{CLEANED_BASE}/demand/Gießen/demand_cleaned.parquet",
    "heidelberg":    f"{CLEANED_BASE}/demand/Heidelberg/demand_cleaned.parquet",
    "kaiserslautern":f"{CLEANED_BASE}/demand/Kaiserslautern/demand_cleaned.parquet",
    "kassel":        f"{CLEANED_BASE}/demand/Kassel/demand_cleaned.parquet",
    "leverkusen":    f"{CLEANED_BASE}/demand/Leverkusen/demand_cleaned.parquet",
    "ludwigshafen":  f"{CLEANED_BASE}/demand/Ludwigshafen/demand_cleaned.parquet",
    "mannheim":      f"{CLEANED_BASE}/demand/Mannheim/demand_cleaned.parquet",
    "marburg":       f"{CLEANED_BASE}/demand/Marburg/demand_cleaned.parquet",
    "offenburg":     f"{CLEANED_BASE}/demand/Offenburg/demand_cleaned.parquet",
    "wiesbaden":     f"{CLEANED_BASE}/demand/Wiesbaden/demand_cleaned.parquet",
    "winsen (Luhe)": f"{CLEANED_BASE}/demand/Winsen (Luhe)/demand_cleaned.parquet",
}

# Vorgegebene Exp2-Paare
TRANSFER_PAIRS = {
    "gießen": ["offenburg", "leverkusen", "marburg"],
    "dortmund": ["braunschweig", "marburg", "heidelberg"],
    "wiesbaden": ["ludwigshafen", "kaiserslautern", "heidelberg"],
}

# ── Fine-Tuning-Parameter ────────────────────────────────────
FT_BUDGETS_DAYS = [7, 14, 30]

# Transfer-Strategien (inspiriert von TF Transfer Learning Guide)
# A: Feature Extraction (frozen backbone, new head)
# B: Partial Fine-Tune (frozen → unfreeze top LSTM)
FT_STRATEGIES = ['full_ft', 'feature_extract', 'partial_ft']
FT_EPOCHS       = 20          # weniger als Cold-Start (30), da pre-trained
FT_LR           = 3e-4        # niedrigere LR als von-scratch (1e-3)

PAIR_ROWS = [
    {"target_city": t, "source_city": s, "budget_days": b, "strategy": strat}
    for t, slist in TRANSFER_PAIRS.items()
    for s in slist
    for b in FT_BUDGETS_DAYS
    for strat in FT_STRATEGIES
]

print(f"Geplante Fine-Tune-Runs: {len(PAIR_ROWS)}")
for t, slist in TRANSFER_PAIRS.items():
    print(f"  Target {t}: Sources={slist}, Budgets={FT_BUDGETS_DAYS}")

@dataclass
class V17bConfig:
    aggregation_minutes: int = 60
    train_ratio: float = 0.67
    val_ratio: float = 0.82
    min_events_per_day: float = 3.0
    rolling_days: int = 56
    min_context_obs: int = 20

    ae_window_size: int = 24
    ae_latent_dim: int = 32
    ae_layers: int = 2
    ae_dropout: float = 0.10
    ae_epochs: int = 50
    ae_batch_size: int = 2048
    ae_lr: float = 1e-3
    ae_early_stop: int = 8
    eval_batch_size: int = 2048

    low_demand_q: float = 0.33
    high_demand_q: float = 0.67

    require_contiguous: bool = True
    use_bidirectional: bool = False

    ae_features: List[str] = field(default_factory=lambda: [
        "n_lends", "n_returns",
        "hour_sin", "hour_cos", "dow_sin", "dow_cos",
        "month_sin", "month_cos", "is_weekend"
    ])
    ae_score_features: List[str] = field(default_factory=lambda: ["n_lends", "n_returns"])

    injection_rate: float = 0.015
    injection_seed: int = 42

cfg = V17bConfig()

ae_features    = list(cfg.ae_features)
score_features = list(cfg.ae_score_features)
context_steps  = cfg.ae_window_size - 1

print(f"Feature-Set: {len(ae_features)} Features")
print(f"FT: {FT_EPOCHS} Epochen, LR={FT_LR}")
print(f"Results: {RESULTS_DIR}")
# Out:
# Geplante Fine-Tune-Runs: 81
#   Target gießen: Sources=['offenburg', 'leverkusen', 'marburg'], Budgets=[7, 14, 30]
#   Target dortmund: Sources=['braunschweig', 'marburg', 'heidelberg'], Budgets=[7, 14, 30]
#   Target wiesbaden: Sources=['ludwigshafen', 'kaiserslautern', 'heidelberg'], Budgets=[7, 14, 30]
# Feature-Set: 9 Features
# FT: 20 Epochen, LR=0.0003
# Results: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs

# %% [markdown]
# ---
# ## Exp3-spezifische Helpers
#
# - `prepare_source_artifacts`: Lädt Source-Modell + berechnet Source-Threshold (identisch zu Exp2)
# - `run_finetune_transfer`: Fine-Tuning des Source-Modells auf Target-Budget, dann zweifache Evaluation

# %%
# ══════════════════════════════════════════════════════════════
# Exp3-1 — Fine-Tune Helpers (mit Transfer-Strategien)
# ══════════════════════════════════════════════════════════════
# Drei Strategien nach TensorFlow Transfer Learning Guide:
#
# A) Feature Extraction ("frozen backbone + new head"):
#    - Alle LSTM-Layer einfrieren (trainable=False)
#    - Nur Output-Dense-Layer wird neu trainiert
#    - Analogie: base_model.trainable = False; neuer Classifier obendrauf
#    - Wenig Parameter → schnell, aber begrenzte Anpassung
#
# B) Partial Fine-Tune ("unfreeze top layers"):
#    - Phase 1: Feature Extraction (frozen backbone, 10 Epochen)
#    - Phase 2: forecast_lstm_2 + forecast_output unfreezen, niedrige LR
#    - Analogie: erst Classifier trainieren, dann top layers fine-tunen
#    - Verhindert catastrophic forgetting der unteren Repräsentationen
#
# C) Full Fine-Tune ("alles offen"):
#    - Alle Layer trainierbar mit niedriger LR
#    - Maximale Anpassung, aber Risiko von Overfitting bei wenig Daten
# ══════════════════════════════════════════════════════════════

def compute_best_f1_threshold(y_true, scores):
    y_true = np.asarray(y_true).astype(int)
    scores = np.asarray(scores).astype(float)
    if len(np.unique(y_true)) <= 1:
        thr = float(np.quantile(scores, 0.99)) if len(scores) else 0.0
        return thr, np.nan, "fallback_99pct"
    prec, rec, thr = precision_recall_curve(y_true, scores)
    if len(thr) == 0:
        thr_val = float(np.quantile(scores, 0.99)) if len(scores) else 0.0
        return thr_val, np.nan, "fallback_99pct"
    f1 = 2 * prec[:-1] * rec[:-1] / (prec[:-1] + rec[:-1] + 1e-12)
    best_idx = int(np.nanargmax(f1))
    return float(thr[best_idx]), float(f1[best_idx]), "source_val_best_f1"

def evaluate_fixed_threshold(meta, score_col, threshold, experiment_name,
                              val_start, test_start, verbose=True):
    meta = meta.copy()
    meta["split_eval"] = np.where(
        meta["hour_ts"] < val_start, "train",
        np.where(meta["hour_ts"] < test_start, "val", "test"))
    test_m = meta[meta["split_eval"] == "test"].copy()
    results = {"experiment": experiment_name, "val_threshold": float(threshold), "n_test": len(test_m)}
    if len(test_m) == 0:
        return results
    y_test = test_m["synth_label"].astype(int).values
    s_test = test_m[score_col].values
    p_test = (s_test >= threshold).astype(int)
    results["n_test_anom"] = int((y_test == 1).sum())
    if len(np.unique(y_test)) > 1:
        results["test_pr_auc_raw"] = float(average_precision_score(y_test, s_test))
    results["test_f1"] = float(f1_score(y_test, p_test, zero_division=0))
    results["test_prec"] = float(precision_score(y_test, p_test, zero_division=0))
    results["test_recall"] = float(recall_score(y_test, p_test, zero_division=0))
    results["pred_pos_rate_test"] = float(p_test.mean())
    if verbose:
        print(f"  [{experiment_name}]")
        print(f"    TEST raw PR-AUC={results.get('test_pr_auc_raw', 'N/A'):.4f}, "
              f"F1={results['test_f1']:.4f}, Prec={results['test_prec']:.4f}, "
              f"Recall={results['test_recall']:.4f}")
    return results

def prepare_source_artifacts(source_city, cfg, source_models_dir):
    """Identisch zu Exp2."""
    global ae_features, score_features, context_steps
    city_key = city_to_key(source_city)
    source_model_path = f"{source_models_dir}/{city_key}_oracle_forecaster.keras"
    print("="*90)
    print(f"[SOURCE] Vorbereitung f\u00fcr {source_city}")
    print("="*90)
    df_src, profile_src, train_end_src, val_end_src = prepare_city_data(
        CITY_DEMAND_ALL[source_city], geo_path, station_names_path, cfg, source_city)
    df_src_inj = inject_synthetic_anomalies_v17b(
        df_src, inject_start=train_end_src,
        injection_rate=cfg.injection_rate, seed=cfg.injection_seed, verbose=True)
    source_data = build_sequences_for_city(
        df_clean=df_src, df_inj=df_src_inj,
        train_end=train_end_src, val_end=val_end_src,
        city_name=source_city, scaler_ext=None)
    source_data["meta_all"] = add_station_demand_weight(source_data["meta_all"])
    if os.path.exists(source_model_path):
        source_model = keras.models.load_model(source_model_path, compile=False)
        print(f"[SOURCE] Oracle-Modell geladen: {source_model_path}")
    else:
        raise FileNotFoundError(f"Source-Modell fehlt: {source_model_path}")
    X_all = source_data["X_all"]
    meta  = source_data["meta_all"].copy()
    meta["score_fc_raw"] = compute_forecast_scores(
        source_model, X_all[:, :context_steps, :], X_all[:, -1, :],
        score_features, ae_features, mode="directional")
    val_mask = meta["split_eval"] == "val"
    y_val = meta.loc[val_mask, "synth_label"].astype(int).values
    s_val = meta.loc[val_mask, "score_fc_raw"].values
    source_threshold, source_best_f1, thr_source = compute_best_f1_threshold(y_val, s_val)
    print(f"[SOURCE] Threshold ({thr_source}) = {source_threshold:.6f}")
    return {
        "source_city": source_city,
        "source_model": source_model,
        "source_scaler": source_data["scaler"],
        "source_threshold_raw": source_threshold,
        "source_model_path": source_model_path,
    }


# ══════════════════════════════════════════════════════════════
# Transfer-Strategie: Modell bauen + trainieren
# ══════════════════════════════════════════════════════════════

def _apply_strategy_feature_extract(source_model, X_train, Y_train,
                                     ft_epochs, ft_lr, batch_size):
    """
    Strategy A: Feature Extraction (Frozen Backbone + New Head)
    - Kopiere Source-Gewichte
    - Friere alle LSTM-Layer ein
    - Ersetze Output-Dense-Layer (neu initialisiert)
    - Trainiere nur den neuen Head
    """
    ft_model = build_lstm_forecaster(
        n_input_features=len(ae_features),
        n_output_features=len(score_features),
        context_steps=context_steps,
        latent_dim=cfg.ae_latent_dim, n_layers=2, dropout=cfg.ae_dropout)

    # Source-Gewichte laden
    ft_model.set_weights(source_model.get_weights())

    # LSTM-Layer einfrieren
    for layer in ft_model.layers:
        if "lstm" in layer.name:
            layer.trainable = False

    # Output-Layer neu initialisieren (frischer Head)
    for layer in ft_model.layers:
        if layer.name == "forecast_output":
            # Gewichte neu initialisieren
            new_weights = [
                tf.keras.initializers.GlorotUniform()(shape=w.shape).numpy()
                if i == 0 else tf.zeros(w.shape).numpy()
                for i, w in enumerate(layer.get_weights())
            ]
            layer.set_weights(new_weights)

    trainable_count = sum(np.prod(v.shape) for v in ft_model.trainable_variables)
    total_count = sum(np.prod(v.shape) for v in ft_model.variables)
    print(f"    [Feature Extract] Trainable: {trainable_count:,} / {total_count:,} params")

    ft_model, history = train_model_fixed_epochs(
        ft_model, X_train, Y_train,
        epochs=ft_epochs, lr=ft_lr * 3,  # h\u00f6here LR f\u00fcr neuen Head ok
        batch_size=batch_size, verbose=0)

    return ft_model, history


def _apply_strategy_partial_ft(source_model, X_train, Y_train,
                                ft_epochs, ft_lr, batch_size):
    """
    Strategy B: Partial Fine-Tune (2-Phasen nach TF Guide)
    Phase 1: Frozen Backbone, nur Head trainieren (Aufwärmen)
    Phase 2: forecast_lstm_2 + Head unfreezen, niedrige LR
    """
    ft_model = build_lstm_forecaster(
        n_input_features=len(ae_features),
        n_output_features=len(score_features),
        context_steps=context_steps,
        latent_dim=cfg.ae_latent_dim, n_layers=2, dropout=cfg.ae_dropout)
    ft_model.set_weights(source_model.get_weights())

    # Phase 1: Alles einfrieren ausser Output
    for layer in ft_model.layers:
        if "lstm" in layer.name:
            layer.trainable = False

    phase1_epochs = max(5, ft_epochs // 3)
    print(f"    [Partial FT] Phase 1: {phase1_epochs} Ep, nur Head")
    ft_model, _ = train_model_fixed_epochs(
        ft_model, X_train, Y_train,
        epochs=phase1_epochs, lr=ft_lr * 3,
        batch_size=batch_size, verbose=0)

    # Phase 2: Top-LSTM aufmachen
    for layer in ft_model.layers:
        if layer.name == "forecast_lstm_2":
            layer.trainable = True

    phase2_epochs = ft_epochs - phase1_epochs
    trainable_count = sum(np.prod(v.shape) for v in ft_model.trainable_variables)
    total_count = sum(np.prod(v.shape) for v in ft_model.variables)
    print(f"    [Partial FT] Phase 2: {phase2_epochs} Ep, lstm_2+Head "
          f"({trainable_count:,}/{total_count:,} params), LR={ft_lr}")
    ft_model, history = train_model_fixed_epochs(
        ft_model, X_train, Y_train,
        epochs=phase2_epochs, lr=ft_lr,
        batch_size=batch_size, verbose=0)

    return ft_model, history


def _apply_strategy_full_ft(source_model, X_train, Y_train,
                             ft_epochs, ft_lr, batch_size):
    """
    Strategy C: Full Fine-Tune (alle Layer offen, niedrige LR)
    """
    ft_model = build_lstm_forecaster(
        n_input_features=len(ae_features),
        n_output_features=len(score_features),
        context_steps=context_steps,
        latent_dim=cfg.ae_latent_dim, n_layers=2, dropout=cfg.ae_dropout)
    ft_model.set_weights(source_model.get_weights())

    # Alle Layer trainierbar (default)
    trainable_count = sum(np.prod(v.shape) for v in ft_model.trainable_variables)
    print(f"    [Full FT] Alle {trainable_count:,} params trainierbar, LR={ft_lr}")

    ft_model, history = train_model_fixed_epochs(
        ft_model, X_train, Y_train,
        epochs=ft_epochs, lr=ft_lr,
        batch_size=batch_size, verbose=0)

    return ft_model, history


STRATEGY_DISPATCH = {
    "feature_extract": _apply_strategy_feature_extract,
    "partial_ft":      _apply_strategy_partial_ft,
    "full_ft":         _apply_strategy_full_ft,
}


def run_finetune_transfer(source_artifacts, target_city, cfg, budget_days,
                           strategy, ft_epochs, ft_lr, models_dir, seed_offset=0):
    """
    Pre-Train + Fine-Tune mit wählbarer Transfer-Strategie.
    """
    global ae_features, score_features, context_steps

    source_city = source_artifacts["source_city"]
    pair_id = f"{source_city}\u2192{target_city}"
    print(f"\n[FINE-TUNE] {pair_id} | Budget={budget_days}d | Strategy={strategy}")

    # ── Target-Daten mit SOURCE-Scaler ───────────────────────
    df_tgt, profile_tgt, train_end_tgt, val_end_tgt = prepare_city_data(
        CITY_DEMAND_ALL[target_city], geo_path, station_names_path, cfg, target_city)
    df_tgt_inj = inject_synthetic_anomalies_v17b(
        df_tgt, inject_start=train_end_tgt,
        injection_rate=cfg.injection_rate, seed=cfg.injection_seed + seed_offset, verbose=True)
    target_data = build_sequences_for_city(
        df_clean=df_tgt, df_inj=df_tgt_inj,
        train_end=train_end_tgt, val_end=val_end_tgt,
        city_name=target_city, scaler_ext=source_artifacts["source_scaler"])
    if target_data is None:
        return None, None
    target_data["meta_all"] = add_station_demand_weight(target_data["meta_all"])

    X_all = target_data["X_all"]
    meta  = target_data["meta_all"].copy()

    # ── Budget-Fenster ───────────────────────────────────────
    train_start = meta.loc[meta["split_eval"] == "train", "hour_ts"].min()
    budget_end  = train_start + pd.Timedelta(days=budget_days)
    budget_end  = min(budget_end, target_data["train_end"])
    budget_mask = (
        (meta["split_eval"] == "train") &
        (meta["label_eval"] == "normal") &
        (meta["hour_ts"] >= train_start) &
        (meta["hour_ts"] < budget_end))
    X_budget = X_all[budget_mask.values]
    n_budget = len(X_budget)
    actual_days = (budget_end - train_start).total_seconds() / 86400
    print(f"  [{target_city}] Budget={budget_days}d, {n_budget} Seq, Strategy={strategy}")

    if n_budget < 10:
        print(f"  [{target_city}] WARNUNG: Nur {n_budget} Seq \u2014 \u00fcbersprungen")
        return None, None

    # ── Strategie anwenden ───────────────────────────────────
    score_idx = [ae_features.index(f) for f in score_features]
    city_key_src = city_to_key(source_city)
    city_key_tgt = city_to_key(target_city)
    model_tag = f"{city_key_src}_to_{city_key_tgt}_{strategy}_{budget_days}d"
    ft_path = f"{models_dir}/{model_tag}_forecaster.keras"

    t_start = time.time()
    batch_size_used = min(cfg.ae_batch_size, max(32, n_budget // 4))

    X_fc_train = X_budget[:, :context_steps, :]
    Y_fc_train = X_budget[:, -1, :][:, score_idx]

    if os.path.exists(ft_path):
        ft_model = keras.models.load_model(ft_path, compile=False)
        print(f"  [{target_city}] Modell geladen von {ft_path}")
    else:
        strategy_fn = STRATEGY_DISPATCH[strategy]
        ft_model, _ = strategy_fn(
            source_artifacts["source_model"],
            X_fc_train, Y_fc_train,
            ft_epochs, ft_lr, batch_size_used)
        ft_model.save(ft_path)
        print(f"  [{target_city}] Modell gespeichert \u2192 {ft_path}")

    train_time = time.time() - t_start

    # ── Scoring ──────────────────────────────────────────────
    X_fc_input    = X_all[:, :context_steps, :]
    X_actual_last = X_all[:, -1, :]
    meta["score_fc_raw"] = compute_forecast_scores(
        ft_model, X_fc_input, X_actual_last,
        score_features, ae_features, mode="directional")

    # ── EVAL A: Strict ───────────────────────────────────────
    result_strict = evaluate_fixed_threshold(
        meta=meta, score_col="score_fc_raw",
        threshold=source_artifacts["source_threshold_raw"],
        experiment_name=f"{pair_id}_{strategy}_{budget_days}d_Strict",
        val_start=target_data["train_end"], test_start=target_data["val_end"])

    # ── EVAL B: Fair ─────────────────────────────────────────
    meta_znorm = znorm_score_by_hour_station(
        meta, "score_fc_raw",
        target_data["train_end"], target_data["val_end"],
        new_col="score_fc_znorm_hs")
    result_fair = evaluate_v17b(
        meta_znorm, "score_fc_znorm_hs",
        f"{pair_id}_{strategy}_{budget_days}d_Fair",
        val_start=target_data["train_end"], test_start=target_data["val_end"])

    # ── Raw PR-AUC ───────────────────────────────────────────
    test_m = meta[meta["split_eval"] == "test"]
    y_test = test_m["synth_label"].astype(int).values
    raw_pr_auc = None
    if len(np.unique(y_test)) > 1:
        raw_pr_auc = float(average_precision_score(y_test, test_m["score_fc_raw"].values))

    combined = {
        "source_city": source_city, "target_city": target_city,
        "pair_id": pair_id, "budget_days": budget_days, "strategy": strategy,
        "n_ft_sequences": n_budget, "actual_ft_days": round(actual_days, 2),
        "ft_epochs": ft_epochs, "ft_lr": ft_lr,
        "train_time_sec": round(train_time, 2),
        "strict_test_pr_auc_raw": result_strict.get("test_pr_auc_raw"),
        "strict_test_f1": result_strict.get("test_f1"),
        "strict_test_prec": result_strict.get("test_prec"),
        "strict_test_recall": result_strict.get("test_recall"),
        "strict_pred_pos_rate": result_strict.get("pred_pos_rate_test"),
        "fair_test_pr_auc": result_fair.get("test_pr_auc"),
        "fair_test_f1": result_fair.get("test_f1"),
        "fair_test_prec": result_fair.get("test_prec"),
        "fair_test_recall": result_fair.get("test_recall"),
        "test_pr_auc_raw": raw_pr_auc,
        "n_test": result_strict.get("n_test"),
        "n_test_anom": result_strict.get("n_test_anom"),
    }
    return combined, meta

# %%
print("RUN_NAME:", RUN_NAME)
print("FT_STRATEGIES:", FT_STRATEGIES)
# Out:
# RUN_NAME: exp03_finetune_pairs_new_pairs
# FT_STRATEGIES: ['full_ft', 'feature_extract', 'partial_ft']

# %% [markdown]
# ---
# ## Exp3-Loop
#
# Pro **Source City** wird einmal das Source-Artefakt geladen (Modell + Threshold).
# Dann werden für alle zugehörigen Targets und Budget-Stufen die Fine-Tune-Runs ausgeführt.
#
# Checkpoint-Mechanismus: Bei Absturz wird ab dem letzten gespeicherten Paar fortgesetzt.

# %%
# ══════════════════════════════════════════════════════════════
# Exp3-2 — Fine-Tune Loop (Multiple Source→Target Pairs × Budgets)
# ══════════════════════════════════════════════════════════════
import gc

pred_dir    = f"{RESULTS_DIR}/predictions"
summary_dir = f"{RESULTS_DIR}/summary"
regime_dir  = f"{RESULTS_DIR}/regime_detail"
for d in [pred_dir, summary_dir, regime_dir]:
    os.makedirs(d, exist_ok=True)

checkpoint_path = f"{summary_dir}/exp03_finetune_pairs_checkpoint.csv"
all_summary_rows = []
done_runs = set()

if os.path.exists(checkpoint_path):
    ckpt_df = pd.read_csv(checkpoint_path)
    all_summary_rows = ckpt_df.to_dict(orient="records")
    if {"source_city", "target_city", "budget_days"}.issubset(ckpt_df.columns):
        done_runs = set(zip(
            ckpt_df["source_city"].astype(str),
            ckpt_df["target_city"].astype(str),
            ckpt_df["budget_days"].astype(int),
            ckpt_df["strategy"].astype(str) if "strategy" in ckpt_df.columns else ["full_ft"]*len(ckpt_df)
        ))
    print(f"Checkpoint geladen: {len(done_runs)} Runs bereits abgeschlossen.")
else:
    print("Kein Checkpoint gefunden. Starte frisch.")

source_cache = {}
n_total = len(PAIR_ROWS)

for i, run in enumerate(PAIR_ROWS, start=1):
    source_city = run["source_city"]
    target_city = run["target_city"]
    budget_days = run["budget_days"]
    strategy   = run["strategy"]
    run_key = (source_city, target_city, budget_days, strategy)

    if run_key in done_runs:
        print(f"\n[{i}/{n_total}] {source_city}\u2192{target_city} {strategy} {budget_days}d bereits im Checkpoint \u2014 \u00fcbersprungen.")
        continue

    print("\n" + "\u2588"*100)
    print(f"\u2588  [{i}/{n_total}] {source_city} \u2192 {target_city} | {strategy} {budget_days}d")
    print("\u2588"*100)

    try:
        # Source-Artefakt cachen
        if source_city not in source_cache:
            source_cache[source_city] = prepare_source_artifacts(
                source_city=source_city, cfg=cfg,
                source_models_dir=SOURCE_MODELS_DIR)

        keras.backend.clear_session()

        result, meta = run_finetune_transfer(
            source_artifacts=source_cache[source_city],
            target_city=target_city, cfg=cfg,
            budget_days=budget_days, strategy=strategy,
            ft_epochs=FT_EPOCHS, ft_lr=FT_LR,
            models_dir=MODELS_DIR,
            seed_offset=i)

        if result is None:
            print(f"  [{source_city}\u2192{target_city} {budget_days}d] Keine Ergebnisse.")
            continue

        # Window-Scores speichern
        model_name = f"fc_{strategy}_{budget_days}d_{city_to_key(source_city)}"
        save_window_level_scores(
            meta, target_city, model_name, pred_dir,
            score_cols=["score_fc_raw"],
            extra_cols=["station_activity_raw", "station_activity_log1p",
                        "station_activity_group"])

        all_summary_rows.append(result)

        # Checkpoint
        pd.DataFrame(all_summary_rows).to_csv(checkpoint_path, index=False)
        print(f"Checkpoint aktualisiert: {checkpoint_path}")

        del meta
        gc.collect()

    except Exception as e:
        print(f"  FEHLER bei {source_city}\u2192{target_city} {budget_days}d: {e}")
        pd.DataFrame(all_summary_rows).to_csv(checkpoint_path, index=False)
        raise

print("\n" + "\u2588"*100)
print("\u2588  Exp3 \u2014 Fine-Tune ABGESCHLOSSEN")
print("\u2588"*100)
# Out:
# Kein Checkpoint gefunden. Starte frisch.
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [1/81] offenburg → gießen | full_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==========================================================================================
# [SOURCE] Vorbereitung für offenburg
# ==========================================================================================
#
# ======================================================================
#   DATEN-PIPELINE: offenburg
# ======================================================================
#   Roh: 143,369 Zeilen, 28 Stationen
#   Zeitraum: 2023-07-20 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (89574, 22)
#   [2] Gap-Fill...
#       89,574 -> 520,689 (+431,115)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (offenburg): 16
#   Regime: {'mid': 6, 'high': 5, 'low': 5}
#   Zeitraum: 2023-07-20 bis 2026-02-02 (929 Tage)
#   Split: Train < 2025-04-02, Val < 2025-08-19, Test ab 2025-08-19
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=1763, injected=1763
#     point_spike: req=1763, inj=1763
#   [offenburg] Scaler gefittet auf 232,017 Train-Zeilen (9 Features)
#   [offenburg] Sequenzen: (349224, 24, 9)
#   [offenburg] Split: {'train': 231649, 'test': 64119, 'val': 53456}
#   [offenburg] X_train (normal): (215189, 24, 9), X_val (normal): (48024, 24, 9)
# [SOURCE] Oracle-Modell geladen: /content/drive/MyDrive/BA_Colab/data/exp01_oracle_scarcity/models/offenburg_oracle_forecaster.keras
# [SOURCE] Threshold (source_val_best_f1) = 1.819569
#
# [FINE-TUNE] offenburg→gießen | Budget=7d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107695, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_full_ft_7d_forecaster.keras
#   [offenburg→gießen_full_ft_7d_Strict]
#     TEST raw PR-AUC=0.3827, F1=0.4568, Prec=0.3196, Recall=0.8005
#
#   [offenburg→gießen_full_ft_7d_Fair]
#     TEST PR-AUC=0.3860, F1=0.4584, Prec=0.4689, Recall=0.4484
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_7d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [2/81] offenburg → gießen | feature_extract 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=7d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107701, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_feature_extract_7d_forecaster.keras
#   [offenburg→gießen_feature_extract_7d_Strict]
#     TEST raw PR-AUC=0.3222, F1=0.3504, Prec=0.2207, Recall=0.8488
#
#   [offenburg→gießen_feature_extract_7d_Fair]
#     TEST PR-AUC=0.3982, F1=0.4464, Prec=0.4679, Recall=0.4268
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_7d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [3/81] offenburg → gießen | partial_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=7d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107697, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_partial_ft_7d_forecaster.keras
#   [offenburg→gießen_partial_ft_7d_Strict]
#     TEST raw PR-AUC=0.3873, F1=0.4551, Prec=0.3151, Recall=0.8192
#
#   [offenburg→gießen_partial_ft_7d_Fair]
#     TEST PR-AUC=0.3941, F1=0.4683, Prec=0.4673, Recall=0.4693
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_7d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [4/81] offenburg → gießen | full_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=14d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107700, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_full_ft_14d_forecaster.keras
#   [offenburg→gießen_full_ft_14d_Strict]
#     TEST raw PR-AUC=0.4166, F1=0.4758, Prec=0.3350, Recall=0.8209
#
#   [offenburg→gießen_full_ft_14d_Fair]
#     TEST PR-AUC=0.4088, F1=0.4830, Prec=0.4612, Recall=0.5070
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_14d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [5/81] offenburg → gießen | feature_extract 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=14d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107740, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_feature_extract_14d_forecaster.keras
#   [offenburg→gießen_feature_extract_14d_Strict]
#     TEST raw PR-AUC=0.3347, F1=0.3475, Prec=0.2165, Recall=0.8792
#
#   [offenburg→gießen_feature_extract_14d_Fair]
#     TEST PR-AUC=0.4210, F1=0.4908, Prec=0.4833, Recall=0.4985
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_14d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [6/81] offenburg → gießen | partial_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=14d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107731, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_partial_ft_14d_forecaster.keras
#   [offenburg→gießen_partial_ft_14d_Strict]
#     TEST raw PR-AUC=0.3881, F1=0.4542, Prec=0.3138, Recall=0.8221
#
#   [offenburg→gießen_partial_ft_14d_Fair]
#     TEST PR-AUC=0.3846, F1=0.4610, Prec=0.4456, Recall=0.4776
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_14d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [7/81] offenburg → gießen | full_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=30d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107725, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_full_ft_30d_forecaster.keras
#   [offenburg→gießen_full_ft_30d_Strict]
#     TEST raw PR-AUC=0.4208, F1=0.4756, Prec=0.3425, Recall=0.7776
#
#   [offenburg→gießen_full_ft_30d_Fair]
#     TEST PR-AUC=0.4065, F1=0.4649, Prec=0.4797, Recall=0.4509
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_30d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [8/81] offenburg → gießen | feature_extract 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=30d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107747, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_feature_extract_30d_forecaster.keras
#   [offenburg→gießen_feature_extract_30d_Strict]
#     TEST raw PR-AUC=0.3170, F1=0.3302, Prec=0.2027, Recall=0.8893
#
#   [offenburg→gießen_feature_extract_30d_Fair]
#     TEST PR-AUC=0.4037, F1=0.4724, Prec=0.4910, Recall=0.4551
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_30d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [9/81] offenburg → gießen | partial_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] offenburg→gießen | Budget=30d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107742, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/offenburg_to_gie_en_partial_ft_30d_forecaster.keras
#   [offenburg→gießen_partial_ft_30d_Strict]
#     TEST raw PR-AUC=0.4042, F1=0.4717, Prec=0.3374, Recall=0.7835
#
#   [offenburg→gießen_partial_ft_30d_Fair]
#     TEST PR-AUC=0.3925, F1=0.4481, Prec=0.4889, Recall=0.4136
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_30d_offenburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [10/81] leverkusen → gießen | full_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==========================================================================================
# [SOURCE] Vorbereitung für leverkusen
# ==========================================================================================
#
# ======================================================================
#   DATEN-PIPELINE: leverkusen
# ======================================================================
#   Roh: 600,845 Zeilen, 149 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (425152, 22)
#   [2] Gap-Fill...
#       425,152 -> 2,292,095 (+1,866,943)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (leverkusen): 71
#   Regime: {'high': 30, 'low': 30, 'mid': 29}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=10957, injected=10957
#     point_spike: req=10957, inj=10957
#   [leverkusen] Scaler gefittet auf 1,289,462 Train-Zeilen (9 Features)
#   [leverkusen] Sequenzen: (1232955, 24, 9)
#   [leverkusen] Split: {'train': 765807, 'test': 255654, 'val': 211494}
#   [leverkusen] X_train (normal): (702514, 24, 9), X_val (normal): (184953, 24, 9)
# [SOURCE] Oracle-Modell geladen: /content/drive/MyDrive/BA_Colab/data/exp01_oracle_scarcity/models/leverkusen_oracle_forecaster.keras
# [SOURCE] Threshold (source_val_best_f1) = 1.770501
#
# [FINE-TUNE] leverkusen→gießen | Budget=7d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107714, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_full_ft_7d_forecaster.keras
#   [leverkusen→gießen_full_ft_7d_Strict]
#     TEST raw PR-AUC=0.3814, F1=0.4550, Prec=0.3198, Recall=0.7882
#
#   [leverkusen→gießen_full_ft_7d_Fair]
#     TEST PR-AUC=0.3950, F1=0.4834, Prec=0.4606, Recall=0.5086
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_7d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [11/81] leverkusen → gießen | feature_extract 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=7d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107708, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_feature_extract_7d_forecaster.keras
#   [leverkusen→gießen_feature_extract_7d_Strict]
#     TEST raw PR-AUC=0.3283, F1=0.3638, Prec=0.2309, Recall=0.8575
#
#   [leverkusen→gießen_feature_extract_7d_Fair]
#     TEST PR-AUC=0.3952, F1=0.4646, Prec=0.4671, Recall=0.4622
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_7d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [12/81] leverkusen → gießen | partial_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=7d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107729, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_partial_ft_7d_forecaster.keras
#   [leverkusen→gießen_partial_ft_7d_Strict]
#     TEST raw PR-AUC=0.3806, F1=0.4461, Prec=0.3081, Recall=0.8078
#
#   [leverkusen→gießen_partial_ft_7d_Fair]
#     TEST PR-AUC=0.4110, F1=0.4890, Prec=0.4710, Recall=0.5085
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_7d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [13/81] leverkusen → gießen | full_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=14d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107714, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_full_ft_14d_forecaster.keras
#   [leverkusen→gießen_full_ft_14d_Strict]
#     TEST raw PR-AUC=0.3785, F1=0.4562, Prec=0.3198, Recall=0.7959
#
#   [leverkusen→gießen_full_ft_14d_Fair]
#     TEST PR-AUC=0.3986, F1=0.4745, Prec=0.4692, Recall=0.4799
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_14d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [14/81] leverkusen → gießen | feature_extract 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=14d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107713, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_feature_extract_14d_forecaster.keras
#   [leverkusen→gießen_feature_extract_14d_Strict]
#     TEST raw PR-AUC=0.3366, F1=0.3251, Prec=0.1973, Recall=0.9229
#
#   [leverkusen→gießen_feature_extract_14d_Fair]
#     TEST PR-AUC=0.3938, F1=0.4635, Prec=0.4663, Recall=0.4608
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_14d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [15/81] leverkusen → gießen | partial_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=14d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107678, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_partial_ft_14d_forecaster.keras
#   [leverkusen→gießen_partial_ft_14d_Strict]
#     TEST raw PR-AUC=0.3698, F1=0.4398, Prec=0.3026, Recall=0.8042
#
#   [leverkusen→gießen_partial_ft_14d_Fair]
#     TEST PR-AUC=0.4062, F1=0.4903, Prec=0.4777, Recall=0.5037
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_14d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [16/81] leverkusen → gießen | full_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=30d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107727, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_full_ft_30d_forecaster.keras
#   [leverkusen→gießen_full_ft_30d_Strict]
#     TEST raw PR-AUC=0.3952, F1=0.4819, Prec=0.3505, Recall=0.7708
#
#   [leverkusen→gießen_full_ft_30d_Fair]
#     TEST PR-AUC=0.4086, F1=0.4769, Prec=0.4672, Recall=0.4871
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_30d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [17/81] leverkusen → gießen | feature_extract 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=30d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107750, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_feature_extract_30d_forecaster.keras
#   [leverkusen→gießen_feature_extract_30d_Strict]
#     TEST raw PR-AUC=0.3449, F1=0.3895, Prec=0.2548, Recall=0.8271
#
#   [leverkusen→gießen_feature_extract_30d_Fair]
#     TEST PR-AUC=0.3953, F1=0.4590, Prec=0.4846, Recall=0.4360
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_30d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [18/81] leverkusen → gießen | partial_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] leverkusen→gießen | Budget=30d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107725, 24, 9)
#   [gießen] Budget=30d, 14393 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/leverkusen_to_gie_en_partial_ft_30d_forecaster.keras
#   [leverkusen→gießen_partial_ft_30d_Strict]
#     TEST raw PR-AUC=0.3778, F1=0.4613, Prec=0.3308, Recall=0.7615
#
#   [leverkusen→gießen_partial_ft_30d_Fair]
#     TEST PR-AUC=0.4118, F1=0.4835, Prec=0.4576, Recall=0.5126
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_30d_leverkusen__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [19/81] marburg → gießen | full_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==========================================================================================
# [SOURCE] Vorbereitung für marburg
# ==========================================================================================
#
# ======================================================================
#   DATEN-PIPELINE: marburg
# ======================================================================
#   Roh: 1,826,429 Zeilen, 60 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (657687, 22)
#   [2] Gap-Fill...
#       657,687 -> 1,269,640 (+611,953)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (marburg): 50
#   Regime: {'mid': 22, 'low': 21, 'high': 21}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=7528, injected=7528
#     point_spike: req=7528, inj=7528
#   [marburg] Scaler gefittet auf 1,002,875 Train-Zeilen (9 Features)
#   [marburg] Sequenzen: (966914, 24, 9)
#   [marburg] Split: {'train': 637795, 'test': 179519, 'val': 149600}
#   [marburg] X_train (normal): (565472, 24, 9), X_val (normal): (127123, 24, 9)
# [SOURCE] Oracle-Modell geladen: /content/drive/MyDrive/BA_Colab/data/exp01_oracle_scarcity/models/marburg_oracle_forecaster.keras
# [SOURCE] Threshold (source_val_best_f1) = 2.980528
#
# [FINE-TUNE] marburg→gießen | Budget=7d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107688, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/marburg_to_gie_en_full_ft_7d_forecaster.keras
#   [marburg→gießen_full_ft_7d_Strict]
#     TEST raw PR-AUC=0.4278, F1=0.3455, Prec=0.4330, Recall=0.2875
#
#   [marburg→gießen_full_ft_7d_Fair]
#     TEST PR-AUC=0.4143, F1=0.4904, Prec=0.4814, Recall=0.4997
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_7d_marburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [20/81] marburg → gießen | feature_extract 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] marburg→gießen | Budget=7d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107732, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/marburg_to_gie_en_feature_extract_7d_forecaster.keras
#   [marburg→gießen_feature_extract_7d_Strict]
#     TEST raw PR-AUC=0.2816, F1=0.2952, Prec=0.2678, Recall=0.3287
#
#   [marburg→gießen_feature_extract_7d_Fair]
#     TEST PR-AUC=0.4212, F1=0.4808, Prec=0.4759, Recall=0.4858
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_feature_extract_7d_marburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [21/81] marburg → gießen | partial_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] marburg→gießen | Budget=7d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107721, 24, 9)
#   [gießen] Budget=7d, 3320 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/marburg_to_gie_en_partial_ft_7d_forecaster.keras
#   [marburg→gießen_partial_ft_7d_Strict]
#     TEST raw PR-AUC=0.4300, F1=0.3482, Prec=0.4400, Recall=0.2881
#
#   [marburg→gießen_partial_ft_7d_Fair]
#     TEST PR-AUC=0.4215, F1=0.4895, Prec=0.4828, Recall=0.4964
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_partial_ft_7d_marburg__window_scores.parquet | rows=696,663
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [22/81] marburg → gießen | full_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] marburg→gießen | Budget=14d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: gießen
# ======================================================================
#   Roh: 1,024,199 Zeilen, 65 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (428409, 22)
#   [2] Gap-Fill...
#       428,409 -> 997,690 (+569,281)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (gießen): 43
#   Regime: {'low': 18, 'high': 18, 'mid': 17}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=6421, injected=6421
#     point_spike: req=6421, inj=6421
#   [gießen] Sequenzen: (696663, 24, 9)
#   [gießen] Split: {'train': 424905, 'test': 148082, 'val': 123676}
#   [gießen] X_train (normal): (381743, 24, 9), X_val (normal): (107766, 24, 9)
#   [gießen] Budget=14d, 6719 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [gießen] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/marburg_to_gie_en_full_ft_14d_forecaster.keras
#   [marburg→gießen_full_ft_14d_Strict]
#     TEST raw PR-AUC=0.4209, F1=0.3301, Prec=0.4251, Recall=0.2698
#
#   [marburg→gießen_full_ft_14d_Fair]
#     TEST PR-AUC=0.4054, F1=0.4763, Prec=0.4716, Recall=0.4811
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/gie_en__fc_full_ft_14d_marburg__window_scores.parquet | rows=696,663
# ...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83845, 24, 9)
#   [wiesbaden] Budget=7d, 3419 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_feature_extract_7d_forecaster.keras
#   [heidelberg→wiesbaden_feature_extract_7d_Strict]
#     TEST raw PR-AUC=0.6656, F1=0.5492, Prec=0.6903, Recall=0.4561
#
#   [heidelberg→wiesbaden_feature_extract_7d_Fair]
#     TEST PR-AUC=0.6155, F1=0.6739, Prec=0.6591, Recall=0.6895
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_feature_extract_7d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [75/81] heidelberg → wiesbaden | partial_ft 7d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=7d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83841, 24, 9)
#   [wiesbaden] Budget=7d, 3419 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_partial_ft_7d_forecaster.keras
#   [heidelberg→wiesbaden_partial_ft_7d_Strict]
#     TEST raw PR-AUC=0.6768, F1=0.5357, Prec=0.7133, Recall=0.4289
#
#   [heidelberg→wiesbaden_partial_ft_7d_Fair]
#     TEST PR-AUC=0.6094, F1=0.6731, Prec=0.6429, Recall=0.7062
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_partial_ft_7d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [76/81] heidelberg → wiesbaden | full_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=14d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83836, 24, 9)
#   [wiesbaden] Budget=14d, 7310 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_full_ft_14d_forecaster.keras
#   [heidelberg→wiesbaden_full_ft_14d_Strict]
#     TEST raw PR-AUC=0.6677, F1=0.5009, Prec=0.6978, Recall=0.3907
#
#   [heidelberg→wiesbaden_full_ft_14d_Fair]
#     TEST PR-AUC=0.6053, F1=0.6814, Prec=0.6487, Recall=0.7176
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_full_ft_14d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [77/81] heidelberg → wiesbaden | feature_extract 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=14d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83793, 24, 9)
#   [wiesbaden] Budget=14d, 7310 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_feature_extract_14d_forecaster.keras
#   [heidelberg→wiesbaden_feature_extract_14d_Strict]
#     TEST raw PR-AUC=0.6327, F1=0.5433, Prec=0.6811, Recall=0.4518
#
#   [heidelberg→wiesbaden_feature_extract_14d_Fair]
#     TEST PR-AUC=0.5969, F1=0.6552, Prec=0.6262, Recall=0.6871
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_feature_extract_14d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [78/81] heidelberg → wiesbaden | partial_ft 14d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=14d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83836, 24, 9)
#   [wiesbaden] Budget=14d, 7310 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_partial_ft_14d_forecaster.keras
#   [heidelberg→wiesbaden_partial_ft_14d_Strict]
#     TEST raw PR-AUC=0.6662, F1=0.5226, Prec=0.7027, Recall=0.4160
#
#   [heidelberg→wiesbaden_partial_ft_14d_Fair]
#     TEST PR-AUC=0.5923, F1=0.6610, Prec=0.6463, Recall=0.6764
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_partial_ft_14d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [79/81] heidelberg → wiesbaden | full_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=30d | Strategy=full_ft
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83833, 24, 9)
#   [wiesbaden] Budget=30d, 15989 Seq, Strategy=full_ft
#     [Full FT] Alle 13,762 params trainierbar, LR=0.0003
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_full_ft_30d_forecaster.keras
#   [heidelberg→wiesbaden_full_ft_30d_Strict]
#     TEST raw PR-AUC=0.6551, F1=0.5138, Prec=0.7012, Recall=0.4054
#
#   [heidelberg→wiesbaden_full_ft_30d_Fair]
#     TEST PR-AUC=0.5937, F1=0.6713, Prec=0.6265, Recall=0.7231
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_full_ft_30d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [80/81] heidelberg → wiesbaden | feature_extract 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=30d | Strategy=feature_extract
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83845, 24, 9)
#   [wiesbaden] Budget=30d, 15989 Seq, Strategy=feature_extract
#     [Feature Extract] Trainable: 66 / 13,766 params
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_feature_extract_30d_forecaster.keras
#   [heidelberg→wiesbaden_feature_extract_30d_Strict]
#     TEST raw PR-AUC=0.6687, F1=0.5371, Prec=0.6903, Recall=0.4396
#
#   [heidelberg→wiesbaden_feature_extract_30d_Fair]
#     TEST PR-AUC=0.5907, F1=0.6540, Prec=0.5962, Recall=0.7242
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_feature_extract_30d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  [81/81] heidelberg → wiesbaden | partial_ft 30d
# ████████████████████████████████████████████████████████████████████████████████████████████████████
#
# [FINE-TUNE] heidelberg→wiesbaden | Budget=30d | Strategy=partial_ft
#
# ======================================================================
#   DATEN-PIPELINE: wiesbaden
# ======================================================================
#   Roh: 152,302 Zeilen, 36 Stationen
#   Zeitraum: 2023-03-31 bis 2026-02-02
#
#   [1] Aggregation...
#       Shape: (115888, 22)
#   [2] Gap-Fill...
#       115,888 -> 892,207 (+776,319)
#   [3] Stationen, Regime, Splits...
#   Aktive Stationen (wiesbaden): 25
#   Regime: {'mid': 9, 'high': 8, 'low': 8}
#   Zeitraum: 2023-03-31 bis 2026-02-02 (1040 Tage)
#   Split: Train < 2025-02-25, Val < 2025-07-30, Test ab 2025-07-30
#   [4] Statistische Scoring-Pipeline...
#   Injection: requested=3033, injected=3033
#     point_spike: req=3033, inj=3033
#   [wiesbaden] Sequenzen: (618779, 24, 9)
#   [wiesbaden] Split: {'train': 416570, 'test': 108709, 'val': 93500}
#   [wiesbaden] X_train (normal): (385813, 24, 9), X_val (normal): (83835, 24, 9)
#   [wiesbaden] Budget=30d, 15989 Seq, Strategy=partial_ft
#     [Partial FT] Phase 1: 6 Ep, nur Head
#     [Partial FT] Phase 2: 14 Ep, lstm_2+Head (8,386/13,766 params), LR=0.0003
#   [wiesbaden] Modell gespeichert → /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/models/heidelberg_to_wiesbaden_partial_ft_30d_forecaster.keras
#   [heidelberg→wiesbaden_partial_ft_30d_Strict]
#     TEST raw PR-AUC=0.6679, F1=0.5206, Prec=0.7013, Recall=0.4140
#
#   [heidelberg→wiesbaden_partial_ft_30d_Fair]
#     TEST PR-AUC=0.5976, F1=0.6750, Prec=0.6374, Recall=0.7173
#   Gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/predictions/wiesbaden__fc_partial_ft_30d_heidelberg__window_scores.parquet | rows=618,779
# Checkpoint aktualisiert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/exp03_finetune_pairs_checkpoint.csv
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# █  Exp3 — Fine-Tune ABGESCHLOSSEN
# ████████████████████████████████████████████████████████████████████████████████████████████████████

# %%
# ══════════════════════════════════════════════════════════════
# Exp3-3 — Summary speichern + anzeigen
# ══════════════════════════════════════════════════════════════
summary_df = pd.DataFrame(all_summary_rows)
summary_path = f"{summary_dir}/V3_exp03_finetune_new_pairs_summary.csv"
summary_df.to_csv(summary_path, index=False)
print(f"Summary gespeichert: {summary_path}")

if len(summary_df) == 0:
    print("Keine Ergebnisse vorhanden.")
else:
    print(f"\n{'='*120}")
    print("ERGEBNISÜBERSICHT: FINE-TUNE (STRICT EVAL)")
    print(f"{'='*120}")
    strict_cols = ["pair_id", "budget_days", "strategy", "n_ft_sequences",
                   "strict_test_pr_auc_raw", "strict_test_f1",
                   "strict_test_prec", "strict_test_recall", "strict_pred_pos_rate"]
    strict_cols = [c for c in strict_cols if c in summary_df.columns]
    print(summary_df[strict_cols].sort_values(
        ["pair_id", "budget_days"]).to_string(index=False))

    print(f"\n{'='*120}")
    print("ERGEBNISÜBERSICHT: FINE-TUNE (FAIR EVAL — Target-Val Z-Norm)")
    print(f"{'='*120}")
    fair_cols = ["pair_id", "budget_days", "strategy", "n_ft_sequences",
                 "fair_test_pr_auc", "fair_test_f1",
                 "fair_test_prec", "fair_test_recall", "test_pr_auc_raw"]
    fair_cols = [c for c in fair_cols if c in summary_df.columns]
    print(summary_df[fair_cols].sort_values(
        ["pair_id", "budget_days"]).to_string(index=False))

    # ── Pro-Paar-Aggregation ─────────────────────────────────
    print(f"\n{'='*120}")
    print("PRO PAAR: Effekt der Budget-Stufen auf Raw PR-AUC")
    print(f"{'='*120}")
    for pair_id in sorted(summary_df["pair_id"].unique()):
        pair_df = summary_df[summary_df["pair_id"] == pair_id].sort_values("budget_days")
        print(f"\n  {pair_id}:")
        for _, row in pair_df.iterrows():
            bd = row.get("budget_days", "?")
            raw = row.get("test_pr_auc_raw", None)
            strict_f1 = row.get("strict_test_f1", None)
            fair_f1 = row.get("fair_test_f1", None)
            n_seq = row.get("n_ft_sequences", "?")
            line = f"    {bd:>3}d FT: raw PR-AUC={raw:.4f}" if raw else f"    {bd:>3}d FT: raw PR-AUC=N/A"
            if strict_f1 is not None:
                line += f"  strict-F1={strict_f1:.4f}"
            if fair_f1 is not None:
                line += f"  fair-F1={fair_f1:.4f}"
            line += f"  [{n_seq} seq]"
            print(line)


    # ── Strategie-Vergleich ──────────────────────────────────
    if "strategy" in summary_df.columns:
        print(f"\n{'='*120}")
        print("STRATEGIE-VERGLEICH (Raw PR-AUC, gemittelt über alle Paare)")
        print(f"{'='*120}")
        strat_agg = summary_df.groupby(["strategy", "budget_days"]).agg(
            mean_raw_prauc=("test_pr_auc_raw", "mean"),
            mean_strict_f1=("strict_test_f1", "mean"),
            mean_fair_f1=("fair_test_f1", "mean"),
            n_runs=("test_pr_auc_raw", "count")
        ).round(4).reset_index()
        print(strat_agg.to_string(index=False))
# Out:
# Summary gespeichert: /content/drive/MyDrive/BA_Colab/data/exp03_finetune_pairs_new_pairs/summary/V3_exp03_finetune_new_pairs_summary.csv
#
# ========================================================================================================================
# ERGEBNISÜBERSICHT: FINE-TUNE (STRICT EVAL)
# ========================================================================================================================
#                  pair_id  budget_days        strategy  n_ft_sequences  strict_test_pr_auc_raw  strict_test_f1  strict_test_prec  strict_test_recall  strict_pred_pos_rate
#    braunschweig→dortmund            7         full_ft           11891                0.633244        0.717007          0.654649            0.792496              0.016022
#    braunschweig→dortmund            7 feature_extract           11891                0.584333        0.684556          0.548741            0.909712              0.022143
#    braunschweig→dortmund            7      partial_ft           11891                0.628925        0.713287          0.646798            0.795012              0.015981
#    braunschweig→dortmund           14         full_ft           23912                0.651008        0.718166          0.659754            0.787926              0.015637
#    braunschweig→dortmund           14 feature_extract           23912                0.600180        0.684932          0.602941            0.792730              0.017228
#    braunschweig→dortmund           14      partial_ft           23912                0.650736        0.722316          0.663575            0.792467              0.016387
#    braunschweig→dortmund           30         full_ft           51354                0.632469        0.722581          0.659232            0.799399              0.016356
#    braunschweig→dortmund           30 feature_extract           51354                0.612073        0.685714          0.605701            0.790085              0.017066
#    braunschweig→dortmund           30      partial_ft           51354                0.641635        0.713238          0.650318            0.789637              0.015910
#      heidelberg→dortmund            7         full_ft           11891                0.637429        0.504565          0.637136            0.417661              0.008350
#      heidelberg→dortmund            7 feature_extract           11891                0.607236        0.615385          0.617960            0.612830              0.013316
#      heidelberg→dortmund            7      partial_ft           11891                0.646400        0.538156          0.663765            0.452522              0.009313
#      heidelberg→dortmund           14         full_ft           23912                0.639037        0.528757          0.655172            0.443235              0.008817
#      heidelberg→dortmund           14 feature_extract           23912                0.571278        0.532332          0.563604            0.504348              0.011472
#      heidelberg→dortmund           14      partial_ft           23912                0.646924        0.524544          0.650812            0.439311              0.008736
#      heidelberg→dortmund           30         full_ft           51354                0.634314        0.517548          0.649824            0.430016              0.008624
#      heidelberg→dortmund           30 feature_extract           51354                0.609228        0.521340          0.631111            0.444097              0.009121
#      heidelberg→dortmund           30      partial_ft           51354                0.643988        0.536702          0.660798            0.451846              0.008634
#     heidelberg→wiesbaden            7         full_ft            3419                0.665309        0.522334          0.705665            0.414616              0.007469
#     heidelberg→wiesbaden            7 feature_extract            3419                0.665571        0.549241          0.690294            0.456052              0.008435
#     heidelberg→wiesbaden            7      partial_ft            3419                0.676815        0.535666          0.713262            0.428879              0.007699
#     heidelberg→wiesbaden           14         full_ft            7310                0.667705        0.500919          0.697823            0.390681              0.007184
#     heidelberg→wiesbaden           14 feature_extract            7310                0.632738        0.543253          0.681128            0.451799              0.008481
#     heidelberg→wiesbaden           14      partial_ft            7310                0.666214        0.522613          0.702703            0.416000              0.007488
#     heidelberg→wiesbaden           30         full_ft           15989                0.655117        0.513795          0.701235            0.405425              0.007451
#     heidelberg→wiesbaden           30 feature_extract           15989                0.668654        0.537128          0.690286            0.439592              0.008049
#     heidelberg→wiesbaden           30      partial_ft           15989                0.667938        0.520650          0.701250            0.414022              0.007359
# kaiserslautern→wiesbaden            7         full_ft            3419                0.662716        0.745480          0.713240            0.780772              0.013826
# kaiserslautern→wiesbaden            7 feature_extract            3419                0.662585        0.764609          0.692170            0.853982              0.015390
# kaiserslautern→wiesbaden            7      partial_ft            3419                0.664263        0.765424          0.724182            0.811646              0.014341
# kaiserslautern→wiesbaden           14         full_ft            7310                0.668136        0.762845          0.718590            0.812908              0.014350
# kaiserslautern→wiesbaden           14 feature_extract            7310                0.664711        0.757605          0.689286            0.840959              0.015454
# kaiserslautern→wiesbaden           14      partial_ft            7310                0.667074        0.758787          0.716797            0.806003              0.014129
# kaiserslautern→wiesbaden           30         full_ft           15989                0.661057        0.742696          0.709005            0.779749              0.013688
# kaiserslautern→wiesbaden           30 feature_extract           15989                0.673124        0.775564          0.713065            0.850073              0.015068
# kaiserslautern→wiesbaden           30      partial_ft           15989                0.653696        0.753883          0.712329            0.800587              0.014102
#        leverkusen→gießen            7         full_ft            3320                0.381396        0.454963          0.319762            0.788250              0.027201
#        leverkusen→gießen            7 feature_extract            3320                0.328268        0.363824          0.230895            0.857491              0.041180
#        leverkusen→gießen            7      partial_ft            3320                0.380589        0.446058          0.308096            0.807765              0.028275
#        leverkusen→gießen           14         full_ft            6719                0.378509        0.456221          0.319752            0.795918              0.027181
#        leverkusen→gießen           14 feature_extract            6719                0.336592        0.325140          0.197331            0.922889              0.051607
#        leverkusen→gießen           14      partial_ft            6719                0.369792        0.439776          0.302635            0.804213              0.028964
#        leverkusen→gießen           30         full_ft           14393                0.395205        0.481905          0.350518            0.770846              0.024757
#        leverkusen→gießen           30 feature_extract           14393                0.344920        0.389541          0.254761            0.827129              0.034751
#        leverkusen→gießen           30      partial_ft           14393                0.377804        0.461281          0.330847            0.761496              0.025351
#   ludwigshafen→wiesbaden            7         full_ft            3419                0.661199        0.773975          0.654669            0.946456              0.017634
#   ludwigshafen→wiesbaden            7 feature_extract            3419                0.668720        0.770421          0.640916            0.965517              0.019290
#   ludwigshafen→wiesbaden            7      partial_ft            3419                0.650350        0.768670          0.647570            0.945482              0.017984
#   ludwigshafen→wiesbaden           14         full_ft            7310                0.656064        0.783529          0.668004            0.947368              0.018343
#   ludwigshafen→wiesbaden           14 feature_extract            7310                0.671519        0.766371          0.639618            0.955777              0.019272
#   ludwigshafen→wiesbaden           14      partial_ft            7310                0.667039        0.779523          0.662383            0.946996              0.018609
#   ludwigshafen→wiesbaden           30         full_ft           15989                0.657698        0.782895          0.668881            0.943764              0.018002
#   ludwigshafen→wiesbaden           30 feature_extract           15989                0.643120        0.749712          0.613176            0.964471              0.019548
#   ludwigshafen→wiesbaden           30      partial_ft           15989                0.662375        0.784256          0.666834            0.951868              0.018278
#         marburg→dortmund            7         full_ft           11891                0.641492        0.284680          0.644809            0.182663              0.003709
#         marburg→dortmund            7 feature_extract           11891                0.593795        0.330130          0.577075            0.231196              0.005128
#         marburg→dortmund            7      partial_ft           11891                0.632942        0.264868          0.598338            0.170079              0.003658
#         marburg→dortmund           14         full_ft           23912                0.641531        0.259709          0.618497            0.164363              0.003506
#         marburg→dortmund           14 feature_extract           23912                0.590630        0.275666          0.557339            0.183120              0.004418
#         marburg→dortmund           14      partial_ft           23912                0.649558        0.272622          0.623342            0.174462              0.003821
#         marburg→dortmund           30         full_ft           51354                0.646101        0.284714          0.637076            0.183321              0.003881
#         marburg→dortmund           30 feature_extract           51354                0.626852        0.296857          0.628079            0.194360              0.004114
#         marburg→dortmund           30      partial_ft           51354                0.649633        0.273545          0.628099            0.174847              0.003679
#           marburg→gießen            7         full_ft            3320                0.427830        0.345550          0.432990            0.287492              0.007205
#           marburg→gießen            7 feature_extract            3320                0.281631        0.295159          0.267832            0.328696              0.014296
#           marburg→gießen            7      partial_ft            3320                0.429952        0.348205          0.439963            0.288115              0.007368
#           marburg→gießen           14         full_ft            6719                0.420925        0.330104          0.425144            0.269793              0.007037
#           marburg→gießen           14 feature_extract            6719                0.299053        0.308263          0.269071            0.360818              0.014607
#           marburg→gießen           14      partial_ft            6719                0.416879        0.351557          0.439279            0.293038              0.007118
#           marburg→gießen           30         full_ft           14393                0.426261        0.337273          0.443983            0.271919              0.006510
#           marburg→gießen           30 feature_extract           14393                0.323169        0.312234          0.314399            0.310098              0.010224
#           marburg→gießen           30      partial_ft           14393                0.426501        0.337036          0.444444            0.271437              0.006685
#         offenburg→gießen            7         full_ft            3320                0.382712        0.456812          0.319595            0.800507              0.026708
#         offenburg→gießen            7 feature_extract            3320                0.322193        0.350365          0.220742            0.848780              0.042585
#         offenburg→gießen            7      partial_ft            3320                0.387259        0.455108          0.315075            0.819195              0.028356
#         offenburg→gießen           14         full_ft            6719                0.416583        0.475806          0.334979            0.820932              0.027356
#         offenburg→gießen           14 feature_extract            6719                0.334656        0.347479          0.216525            0.879239              0.046096
#         offenburg→gießen           14      partial_ft            6719                0.388063        0.454244          0.313825            0.822082              0.028039
#         offenburg→gießen           30         full_ft           14393                0.420784        0.475582          0.342532            0.777641              0.024959
#         offenburg→gießen           30 feature_extract           14393                0.316981        0.330175          0.202720            0.889299              0.048169
#         offenburg→gießen           30      partial_ft           14393                0.404246        0.471708          0.337438            0.783455              0.025776
#
# ========================================================================================================================
# ERGEBNISÜBERSICHT: FINE-TUNE (FAIR EVAL — Target-Val Z-Norm)
# ========================================================================================================================
#                  pair_id  budget_days        strategy  n_ft_sequences  fair_test_pr_auc  fair_test_f1  fair_test_prec  fair_test_recall  test_pr_auc_raw
#    braunschweig→dortmund            7         full_ft           11891          0.583479      0.646108        0.634885          0.657734         0.633244
#    braunschweig→dortmund            7 feature_extract           11891          0.539451      0.618947        0.575718          0.669196         0.584333
#    braunschweig→dortmund            7      partial_ft           11891          0.559368      0.636605        0.619469          0.654716         0.628925
#    braunschweig→dortmund           14         full_ft           23912          0.559766      0.634128        0.629771          0.638545         0.651008
#    braunschweig→dortmund           14 feature_extract           23912          0.615382      0.631738        0.616176          0.648105         0.600180
#    braunschweig→dortmund           14      partial_ft           23912          0.585104      0.660637        0.647518          0.674298         0.650736
#    braunschweig→dortmund           30         full_ft           51354          0.561416      0.640921        0.633627          0.648385         0.632469
#    braunschweig→dortmund           30 feature_extract           51354          0.616666      0.626073        0.630999          0.621224         0.612073
#    braunschweig→dortmund           30      partial_ft           51354          0.553844      0.618210        0.611658          0.624903         0.641635
#      heidelberg→dortmund            7         full_ft           11891          0.570310      0.634683        0.627527          0.642005         0.637429
#      heidelberg→dortmund            7 feature_extract           11891          0.559048      0.619777        0.575307          0.671698         0.607236
#      heidelberg→dortmund            7      partial_ft           11891          0.570476      0.646188        0.644756          0.647626         0.646400
#      heidelberg→dortmund           14         full_ft           23912          0.575227      0.652850        0.622881          0.685848         0.639037
#      heidelberg→dortmund           14 feature_extract           23912          0.569551      0.624174        0.613914          0.634783         0.571278
#      heidelberg→dortmund           14      partial_ft           23912          0.584644      0.641452        0.620337          0.664056         0.646924
#      heidelberg→dortmund           30         full_ft           51354          0.565248      0.648607        0.636704          0.660964         0.634314
#      heidelberg→dortmund           30 feature_extract           51354          0.582807      0.622585        0.593064          0.655199         0.609228
#      heidelberg→dortmund           30      partial_ft           51354          0.575134      0.644068        0.632843          0.655698         0.643988
#     heidelberg→wiesbaden            7         full_ft            3419          0.606168      0.665259        0.647704          0.683792         0.665309
#     heidelberg→wiesbaden            7 feature_extract            3419          0.615547      0.673944        0.659091          0.689481         0.665571
#     heidelberg→wiesbaden            7      partial_ft            3419          0.609406      0.673057        0.642904          0.706178         0.676815
#     heidelberg→wiesbaden           14         full_ft            7310          0.605295      0.681416        0.648736          0.717563         0.667705
#     heidelberg→wiesbaden           14 feature_extract            7310          0.596889      0.655232        0.626230          0.687050         0.632738
#     heidelberg→wiesbaden           14      partial_ft            7310          0.592261      0.660981        0.646282          0.676364         0.666214
#     heidelberg→wiesbaden           30         full_ft           15989          0.593748      0.671306        0.626469          0.723055         0.655117
#     heidelberg→wiesbaden           30 feature_extract           15989          0.590693      0.653960        0.596165          0.724163         0.668654
#     heidelberg→wiesbaden           30      partial_ft           15989          0.597591      0.675000        0.637377          0.717343         0.667938
# kaiserslautern→wiesbaden            7         full_ft            3419          0.571509      0.655830        0.636925          0.675892         0.662716
# kaiserslautern→wiesbaden            7 feature_extract            3419          0.586543      0.650138        0.609819          0.696165         0.662585
# kaiserslautern→wiesbaden            7      partial_ft            3419          0.584002      0.649049        0.636489          0.662114         0.664263
# kaiserslautern→wiesbaden           14         full_ft            7310          0.606190      0.682464        0.640000          0.730964         0.668136
# kaiserslautern→wiesbaden           14 feature_extract            7310          0.611568      0.672297        0.628553          0.722585         0.664711
# kaiserslautern→wiesbaden           14      partial_ft            7310          0.575904      0.663389        0.600593          0.740849         0.667074
# kaiserslautern→wiesbaden           30         full_ft           15989          0.583843      0.656633        0.623670          0.693274         0.661057
# kaiserslautern→wiesbaden           30 feature_extract           15989          0.602873      0.668291        0.640427          0.698690         0.673124
# kaiserslautern→wiesbaden           30      partial_ft           15989          0.590112      0.659269        0.594118          0.740469         0.653696
#        leverkusen→gießen            7         full_ft            3320          0.395028      0.483421        0.460643          0.508568         0.381396
#        leverkusen→gießen            7 feature_extract            3320          0.395190      0.464646        0.467077          0.462241         0.328268
#        leverkusen→gießen            7      partial_ft            3320          0.410961      0.489009        0.470998          0.508453         0.380589
#        leverkusen→gießen           14         full_ft            6719          0.398578      0.474473        0.469166          0.479901         0.378509
#        leverkusen→gießen           14 feature_extract            6719          0.393827      0.463527        0.466254          0.460832         0.336592
#        leverkusen→gießen           14      partial_ft            6719          0.406244      0.490350        0.477673          0.503717         0.369792
#        leverkusen→gießen           30         full_ft           14393          0.408630      0.476946        0.467204          0.487103         0.395205
#        leverkusen→gießen           30 feature_extract           14393          0.395260      0.458984        0.484572          0.435962         0.344920
#        leverkusen→gießen           30      partial_ft           14393          0.411791      0.483516        0.457581          0.512569         0.377804
#   ludwigshafen→wiesbaden            7         full_ft            3419          0.578487      0.648299        0.590458          0.718703         0.661199
#   ludwigshafen→wiesbaden            7 feature_extract            3419          0.600506      0.653061        0.629753          0.678161         0.668720
#   ludwigshafen→wiesbaden            7      partial_ft            3419          0.584926      0.652616        0.635527          0.670650         0.650350
#   ludwigshafen→wiesbaden           14         full_ft            7310          0.605931      0.665289        0.644860          0.687055         0.656064
#   ludwigshafen→wiesbaden           14 feature_extract            7310          0.608197      0.676617        0.632362          0.727532         0.671519
#   ludwigshafen→wiesbaden           14      partial_ft            7310          0.617436      0.675501        0.650524          0.702473         0.667039
#   ludwigshafen→wiesbaden           30         full_ft           15989          0.584559      0.648592        0.633861          0.664023         0.657698
#   ludwigshafen→wiesbaden           30 feature_extract           15989          0.565018      0.642094        0.600515          0.689859         0.643120
#   ludwigshafen→wiesbaden           30      partial_ft           15989          0.597831      0.653899        0.624021          0.686782         0.662375
#         marburg→dortmund            7         full_ft           11891          0.592187      0.636293        0.640282          0.632353         0.641492
#         marburg→dortmund            7 feature_extract           11891          0.538206      0.623505        0.561115          0.701504         0.593795
#         marburg→dortmund            7      partial_ft           11891          0.605280      0.646095        0.625830          0.667717         0.632942
#         marburg→dortmund           14         full_ft           23912          0.603989      0.649618        0.645675          0.653610         0.641531
#         marburg→dortmund           14 feature_extract           23912          0.622576      0.643357        0.628777          0.658628         0.590630
#         marburg→dortmund           14      partial_ft           23912          0.626573      0.665452        0.653543          0.677803         0.649558
#         marburg→dortmund           30         full_ft           51354          0.592851      0.644968        0.642325          0.647633         0.646101
#         marburg→dortmund           30 feature_extract           51354          0.630471      0.647647        0.630137          0.666159         0.626852
#         marburg→dortmund           30      partial_ft           51354          0.609396      0.645236        0.651800          0.638804         0.649633
#           marburg→gießen            7         full_ft            3320          0.414321      0.490382        0.481415          0.499689         0.427830
#           marburg→gießen            7 feature_extract            3320          0.421183      0.480780        0.475866          0.485797         0.281631
#           marburg→gießen            7      partial_ft            3320          0.421548      0.489494        0.482779          0.496399         0.429952
#           marburg→gießen           14         full_ft            6719          0.405365      0.476334        0.471642          0.481121         0.420925
#           marburg→gießen           14 feature_extract            6719          0.374490      0.449536        0.448980          0.450093         0.299053
#           marburg→gießen           14      partial_ft            6719          0.390817      0.455243        0.459948          0.450633         0.416879
#           marburg→gießen           30         full_ft           14393          0.421064      0.487608        0.475816          0.500000         0.426261
#           marburg→gießen           30 feature_extract           14393          0.359500      0.422937        0.430499          0.415635         0.323169
#           marburg→gießen           30      partial_ft           14393          0.399281      0.467417        0.449573          0.486737         0.426501
#         offenburg→gießen            7         full_ft            3320          0.385959      0.458401        0.468874          0.448385         0.382712
#         offenburg→gießen            7 feature_extract            3320          0.398193      0.446429        0.467914          0.426829         0.322193
#         offenburg→gießen            7      partial_ft            3320          0.394055      0.468335        0.467324          0.469350         0.387259
#         offenburg→gießen           14         full_ft            6719          0.408754      0.482997        0.461200          0.506957         0.416583
#         offenburg→gießen           14 feature_extract            6719          0.420959      0.490776        0.483276          0.498513         0.334656
#         offenburg→gießen           14      partial_ft            6719          0.384637      0.461023        0.445556          0.477603         0.388063
#         offenburg→gießen           30         full_ft           14393          0.406532      0.464851        0.479739          0.450860         0.420784
#         offenburg→gießen           30 feature_extract           14393          0.403723      0.472391        0.491042          0.455105         0.316981
#         offenburg→gießen           30      partial_ft           14393          0.392462      0.448105        0.488857          0.413625         0.404246
#
# ========================================================================================================================
# PRO PAAR: Effekt der Budget-Stufen auf Raw PR-AUC
# ========================================================================================================================
#
#   braunschweig→dortmund:
#       7d FT: raw PR-AUC=0.6332  strict-F1=0.7170  fair-F1=0.6461  [11891 seq]
#       7d FT: raw PR-AUC=0.5843  strict-F1=0.6846  fair-F1=0.6189  [11891 seq]
#       7d FT: raw PR-AUC=0.6289  strict-F1=0.7133  fair-F1=0.6366  [11891 seq]
#      14d FT: raw PR-AUC=0.6510  strict-F1=0.7182  fair-F1=0.6341  [23912 seq]
#      14d FT: raw PR-AUC=0.6002  strict-F1=0.6849  fair-F1=0.6317  [23912 seq]
#      14d FT: raw PR-AUC=0.6507  strict-F1=0.7223  fair-F1=0.6606  [23912 seq]
#      30d FT: raw PR-AUC=0.6325  strict-F1=0.7226  fair-F1=0.6409  [51354 seq]
#      30d FT: raw PR-AUC=0.6121  strict-F1=0.6857  fair-F1=0.6261  [51354 seq]
#      30d FT: raw PR-AUC=0.6416  strict-F1=0.7132  fair-F1=0.6182  [51354 seq]
#
#   heidelberg→dortmund:
#       7d FT: raw PR-AUC=0.6374  strict-F1=0.5046  fair-F1=0.6347  [11891 seq]
#       7d FT: raw PR-AUC=0.6072  strict-F1=0.6154  fair-F1=0.6198  [11891 seq]
#       7d FT: raw PR-AUC=0.6464  strict-F1=0.5382  fair-F1=0.6462  [11891 seq]
#      14d FT: raw PR-AUC=0.6390  strict-F1=0.5288  fair-F1=0.6528  [23912 seq]
#      14d FT: raw PR-AUC=0.5713  strict-F1=0.5323  fair-F1=0.6242  [23912 seq]
#      14d FT: raw PR-AUC=0.6469  strict-F1=0.5245  fair-F1=0.6415  [23912 seq]
#      30d FT: raw PR-AUC=0.6343  strict-F1=0.5175  fair-F1=0.6486  [51354 seq]
#      30d FT: raw PR-AUC=0.6092  strict-F1=0.5213  fair-F1=0.6226  [51354 seq]
#      30d FT: raw PR-AUC=0.6440  strict-F1=0.5367  fair-F1=0.6441  [51354 seq]
#
#   heidelberg→wiesbaden:
#       7d FT: raw PR-AUC=0.6653  strict-F1=0.5223  fair-F1=0.6653  [3419 seq]
#       7d FT: raw PR-AUC=0.6656  strict-F1=0.5492  fair-F1=0.6739  [3419 seq]
#       7d FT: raw PR-AUC=0.6768  strict-F1=0.5357  fair-F1=0.6731  [3419 seq]
#      14d FT: raw PR-AUC=0.6677  strict-F1=0.5009  fair-F1=0.6814  [7310 seq]
#      14d FT: raw PR-AUC=0.6327  strict-F1=0.5433  fair-F1=0.6552  [7310 seq]
#      14d FT: raw PR-AUC=0.6662  strict-F1=0.5226  fair-F1=0.6610  [7310 seq]
#      30d FT: raw PR-AUC=0.6551  strict-F1=0.5138  fair-F1=0.6713  [15989 seq]
#      30d FT: raw PR-AUC=0.6687  strict-F1=0.5371  fair-F1=0.6540  [15989 seq]
#      30d FT: raw PR-AUC=0.6679  strict-F1=0.5206  fair-F1=0.6750  [15989 seq]
#
#   kaiserslautern→wiesbaden:
#       7d FT: raw PR-AUC=0.6627  strict-F1=0.7455  fair-F1=0.6558  [3419 seq]
#       7d FT: raw PR-AUC=0.6626  strict-F1=0.7646  fair-F1=0.6501  [3419 seq]
#       7d FT: raw PR-AUC=0.6643  strict-F1=0.7654  fair-F1=0.6490  [3419 seq]
#      14d FT: raw PR-AUC=0.6681  strict-F1=0.7628  fair-F1=0.6825  [7310 seq]
#      14d FT: raw PR-AUC=0.6647  strict-F1=0.7576  fair-F1=0.6723  [7310 seq]
#      14d FT: raw PR-AUC=0.6671  strict-F1=0.7588  fair-F1=0.6634  [7310 seq]
#      30d FT: raw PR-AUC=0.6611  strict-F1=0.7427  fair-F1=0.6566  [15989 seq]
#      30d FT: raw PR-AUC=0.6731  strict-F1=0.7756  fair-F1=0.6683  [15989 seq]
#      30d FT: raw PR-AUC=0.6537  strict-F1=0.7539  fair-F1=0.6593  [15989 seq]
#
#   leverkusen→gießen:
#       7d FT: raw PR-AUC=0.3814  strict-F1=0.4550  fair-F1=0.4834  [3320 seq]
#       7d FT: raw PR-AUC=0.3283  strict-F1=0.3638  fair-F1=0.4646  [3320 seq]
#       7d FT: raw PR-AUC=0.3806  strict-F1=0.4461  fair-F1=0.4890  [3320 seq]
#      14d FT: raw PR-AUC=0.3785  strict-F1=0.4562  fair-F1=0.4745  [6719 seq]
#      14d FT: raw PR-AUC=0.3366  strict-F1=0.3251  fair-F1=0.4635  [6719 seq]
#      14d FT: raw PR-AUC=0.3698  strict-F1=0.4398  fair-F1=0.4903  [6719 seq]
#      30d FT: raw PR-AUC=0.3952  strict-F1=0.4819  fair-F1=0.4769  [14393 seq]
#      30d FT: raw PR-AUC=0.3449  strict-F1=0.3895  fair-F1=0.4590  [14393 seq]
#      30d FT: raw PR-AUC=0.3778  strict-F1=0.4613  fair-F1=0.4835  [14393 seq]
#
#   ludwigshafen→wiesbaden:
#       7d FT: raw PR-AUC=0.6612  strict-F1=0.7740  fair-F1=0.6483  [3419 seq]
#       7d FT: raw PR-AUC=0.6687  strict-F1=0.7704  fair-F1=0.6531  [3419 seq]
#       7d FT: raw PR-AUC=0.6504  strict-F1=0.7687  fair-F1=0.6526  [3419 seq]
#      14d FT: raw PR-AUC=0.6561  strict-F1=0.7835  fair-F1=0.6653  [7310 seq]
#      14d FT: raw PR-AUC=0.6715  strict-F1=0.7664  fair-F1=0.6766  [7310 seq]
#      14d FT: raw PR-AUC=0.6670  strict-F1=0.7795  fair-F1=0.6755  [7310 seq]
#      30d FT: raw PR-AUC=0.6577  strict-F1=0.7829  fair-F1=0.6486  [15989 seq]
#      30d FT: raw PR-AUC=0.6431  strict-F1=0.7497  fair-F1=0.6421  [15989 seq]
#      30d FT: raw PR-AUC=0.6624  strict-F1=0.7843  fair-F1=0.6539  [15989 seq]
#
#   marburg→dortmund:
#       7d FT: raw PR-AUC=0.6415  strict-F1=0.2847  fair-F1=0.6363  [11891 seq]
#       7d FT: raw PR-AUC=0.5938  strict-F1=0.3301  fair-F1=0.6235  [11891 seq]
#       7d FT: raw PR-AUC=0.6329  strict-F1=0.2649  fair-F1=0.6461  [11891 seq]
#      14d FT: raw PR-AUC=0.6415  strict-F1=0.2597  fair-F1=0.6496  [23912 seq]
#      14d FT: raw PR-AUC=0.5906  strict-F1=0.2757  fair-F1=0.6434  [23912 seq]
#      14d FT: raw PR-AUC=0.6496  strict-F1=0.2726  fair-F1=0.6655  [23912 seq]
#      30d FT: raw PR-AUC=0.6461  strict-F1=0.2847  fair-F1=0.6450  [51354 seq]
#      30d FT: raw PR-AUC=0.6269  strict-F1=0.2969  fair-F1=0.6476  [51354 seq]
#      30d FT: raw PR-AUC=0.6496  strict-F1=0.2735  fair-F1=0.6452  [51354 seq]
#
#   marburg→gießen:
#       7d FT: raw PR-AUC=0.4278  strict-F1=0.3455  fair-F1=0.4904  [3320 seq]
#       7d FT: raw PR-AUC=0.2816  strict-F1=0.2952  fair-F1=0.4808  [3320 seq]
#       7d FT: raw PR-AUC=0.4300  strict-F1=0.3482  fair-F1=0.4895  [3320 seq]
#      14d FT: raw PR-AUC=0.4209  strict-F1=0.3301  fair-F1=0.4763  [6719 seq]
#      14d FT: raw PR-AUC=0.2991  strict-F1=0.3083  fair-F1=0.4495  [6719 seq]
#      14d FT: raw PR-AUC=0.4169  strict-F1=0.3516  fair-F1=0.4552  [6719 seq]
#      30d FT: raw PR-AUC=0.4263  strict-F1=0.3373  fair-F1=0.4876  [14393 seq]
#      30d FT: raw PR-AUC=0.3232  strict-F1=0.3122  fair-F1=0.4229  [14393 seq]
#      30d FT: raw PR-AUC=0.4265  strict-F1=0.3370  fair-F1=0.4674  [14393 seq]
#
#   offenburg→gießen:
#       7d FT: raw PR-AUC=0.3827  strict-F1=0.4568  fair-F1=0.4584  [3320 seq]
#       7d FT: raw PR-AUC=0.3222  strict-F1=0.3504  fair-F1=0.4464  [3320 seq]
#       7d FT: raw PR-AUC=0.3873  strict-F1=0.4551  fair-F1=0.4683  [3320 seq]
#      14d FT: raw PR-AUC=0.4166  strict-F1=0.4758  fair-F1=0.4830  [6719 seq]
#      14d FT: raw PR-AUC=0.3347  strict-F1=0.3475  fair-F1=0.4908  [6719 seq]
#      14d FT: raw PR-AUC=0.3881  strict-F1=0.4542  fair-F1=0.4610  [6719 seq]
#      30d FT: raw PR-AUC=0.4208  strict-F1=0.4756  fair-F1=0.4649  [14393 seq]
#      30d FT: raw PR-AUC=0.3170  strict-F1=0.3302  fair-F1=0.4724  [14393 seq]
#      30d FT: raw PR-AUC=0.4042  strict-F1=0.4717  fair-F1=0.4481  [14393 seq]
#
# ========================================================================================================================
# STRATEGIE-VERGLEICH (Raw PR-AUC, gemittelt über alle Paare)
# ========================================================================================================================
#        strategy  budget_days  mean_raw_prauc  mean_strict_f1  mean_fair_f1  n_runs
# feature_extract            7          0.5238          0.5249        0.5812       9
# feature_extract           14          0.5224          0.5046        0.5897       9
# feature_extract           30          0.5353          0.5109        0.5794       9
#         full_ft            7          0.5659          0.5339        0.5910       9
#         full_ft           14          0.5711          0.5351        0.6000       9
#         full_ft           30          0.5699          0.5399        0.5934       9
#      partial_ft            7          0.5664          0.5373        0.5945       9
#      partial_ft           14          0.5691          0.5362        0.5971       9
#      partial_ft           30          0.5698          0.5391        0.5883       9

# %% [markdown]
# ### Vergleich mit Referenzlinien
#
# Dieses Exp3-Notebook liefert Fine-Tune-Ergebnisse, die direkt vergleichbar sind mit:
# - **Exp01-Oracle**: Obere Schranke (FC auf vollem Target-Train, Fair-Eval)
# - **Exp01-Scarcity**: Target-Only mit gleichem Budget (Fair-Eval)
# - **Exp02-Zero-Shot**: Kein Fine-Tuning (Strict-Eval auf Raw-Scores)
#
# Die zentrale Frage: Verbessert Fine-Tuning die Raw PR-AUC gegenüber Zero-Shot?
# Und: Erreicht Pre-Train + Fine-Tune mit 7d Target-Daten die Leistung von Target-Only mit 7d?
